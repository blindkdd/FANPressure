# %%
import pickle
import networkx as nx
import matplotlib.pyplot as plt
import torch
import dgl
import numpy as np
import torch.nn.functional as F
import torch as th
import torch.nn as nn
from roadModel import roadModel
import envPressureSubsEdges
from scipy.special import softmax

from tensorboardX import SummaryWriter


macrostep = 10
DEVICE = "cuda:1"

# %%
with open("stoppedEdges.pkl", 'rb') as f:
    stoppedEdges = pickle.load(f)
    
with open("amatrix_edges.pkl", 'rb') as f:
    A = pickle.load(f)

# %%
indices = {c:i for i,c in enumerate(list(A.columns))}
invertedIndices = {i:c for i,c in enumerate(list(A.columns))}
g = dgl.DGLGraph(np.eye(A.values.shape[0]) + A.values)
N = g.number_of_nodes()
embedding_n = 32

# %%
environ = envPressureSubsEdges.CornicheEnv(macrostep=macrostep,predefined=False,scale=8,GUI=False)
obs = environ.reset()
# Out:
# Could not connect to TraCI server at localhost:51313 [Errno 111] Connection refused
#  Retrying in 1 seconds

# %% [markdown]
# ## Set nodes and edges attributes

# %%
g.edata['prob'] = torch.ones((g.number_of_edges(),1)).cuda().to(DEVICE)
g.ndata['embedding'] = torch.ones((g.number_of_nodes(),embedding_n)).cuda().to(DEVICE)

# %%
class PredictLeavingModule(nn.Module):
    def __init__(self, in_feats, embedding_n):
        super(PredictLeavingModule, self).__init__()
        self.embed = nn.Embedding(in_feats, embedding_n)
        self.L2 = nn.Linear(embedding_n+1, 1)
        self.A2 = F.relu
        

    def forward(self, node):
        embedding = self.embed(node.data['features'])        
        #stack cars with embedding
        l2input = th.cat((embedding,node.data['cars']),dim=1)

        leaving_cars = self.L2(l2input)
        leaving_cars = self.A2(leaving_cars)
        
        leaving_cars = leaving_cars * node.data['free']
        leaving_cars = th.min(leaving_cars,node.data['cars'])
                
        return {'leaving_cars' : leaving_cars, 'embedding': embedding}

# %%
class PredictEdgeProbModule(nn.Module):
    def __init__(self, embedding_n):
        super(PredictEdgeProbModule, self).__init__()
        self.L2 = nn.Linear(embedding_n*2, 1)
        self.A2 = F.relu

    def forward(self, edge):
        h = torch.cat([edge.src['embedding'], edge.dst['embedding']], dim=1)
        h = self.L2(h)
        logit = self.A2(h)
        
        return {'logit' : logit}

# %%
def flow_message_func(edges):
    return {'c' : edges.src['leaving_cars']*edges.data['prob'], 'e' : edges.src['embedding']}

# %%
def flow_reduce_func(nodes):
    incoming = torch.sum(nodes.mailbox['c'], dim=1)
    cars =  incoming + nodes.data["cars"]
    
    a = th.softmax(th.cat((nodes.mailbox['c'], nodes.data["cars"].unsqueeze(1)),dim=1),dim=1)
    embeddings = th.cat((nodes.mailbox['e'],nodes.data['embedding'].unsqueeze(1)),dim=1)

    
    
    embedding = torch.sum(embeddings*a,dim=1)
    
    
    return {'cars' : cars, 'embedding': embedding}

# %%
def flow_apply_func(nodes):
    cars = nodes.data["cars"] - nodes.data["leaving_cars"]
    return {'cars':cars}

# %%
def softmax_feat(edges): return {'prob': th.softmax(edges.data['logit'], dim=1)}

# %%
class GCN(nn.Module):
    def __init__(self, nodes_feats_size, embedding_n):
        super(GCN, self).__init__()
        self.predict_parking = PredictParkingModule(embedding_n)
        self.predict_leaving = PredictLeavingModule(nodes_feats_size, embedding_n)
        self.predict_edge_prob = PredictEdgeProbModule(embedding_n)

    def forward(self, g, nfeatures):
        g.ndata['features'] = nfeatures
        g.ndata["leaving_cars"] = th.zeros((N,1)).cuda().to(DEVICE)
        
        g.apply_nodes(func=self.predict_leaving)
        g.apply_edges(func=self.predict_edge_prob)
        g.group_apply_edges(func=softmax_feat, group_by='src')
        
        g.pull(v=g.nodes(),message_func=flow_message_func, reduce_func=flow_reduce_func)
        g.apply_nodes(v=g.nodes(),func=flow_apply_func)
        
        g.apply_nodes(v=g.nodes(),func=self.predict_parking)
        

        return g.ndata.pop('cars'),g.ndata.pop('embedding')

# %%
class Net(nn.Module):
    def __init__(self, nfeatures_size, embedding_n):
        super(Net, self).__init__()
        self.gcn = GCN(nfeatures_size, embedding_n)
    
    def forward(self, g, nfeatures, cars, freeEdges):
        g.ndata['cars'] = cars
        g.ndata['free'] = freeEdges
        x = self.gcn(g, nfeatures)
        return x

# %%
net = Net(g.number_of_nodes(),embedding_n)
net.cuda().to(DEVICE)
print(net)
# Out:
# Net(
#   (gcn): GCN(
#     (predict_parking): PredictParkingModule(
#       (L2): Linear(in_features=33, out_features=1, bias=True)
#     )
#     (predict_leaving): PredictLeavingModule(
#       (embed): Embedding(1868, 32)
#       (L2): Linear(in_features=33, out_features=1, bias=True)
#     )
#     (predict_edge_prob): PredictEdgeProbModule(
#       (L2): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )

# %%
import time
import numpy as np

nfeatures = th.eye(g.number_of_nodes())
nids = th.LongTensor([x for x in range(g.number_of_nodes())])

MSE = nn.MSELoss()

optimizer = th.optim.Adam(net.parameters(), lr=1e-3)
dur = []

# %%
TL = len(environ.action_space)

# %%
def send_graph_to_device(g, DEVICE):
    # nodes
    labels = g.node_attr_schemes()
    for l in labels.keys():
        g.ndata[l] = g.ndata.pop(l).cuda().to(DEVICE, non_blocking=True)
    
    # edges
    labels = g.edge_attr_schemes()
    for l in labels.keys():
        g.edata[l] = g.edata.pop(l).cuda().to(DEVICE, non_blocking=True)
    return g

# %%
#g = send_graph_to_device(g,DEVICE)
epochs = 1

for run in range(5):
    obs = environ.reset(restart=(run>0))
    future_cars,phaseobs = obs
    cars = th.FloatTensor(future_cars).unsqueeze(1)
    writer = SummaryWriter(comment="Corniche_GATFlow_OneOmbedding_4steps_%depochs_%d s_Episode%d_002_scale8" % (epochs,macrostep,run))
    
    for i in range(int(24*60*60/macrostep)-1):
        #action = [environ.action_space[tl].sample() for tl in range(TL)]
        action = [ np.random.choice(list(range(environ.action_space[i].n)),p=softmax(phaseobs[i])) for i in range(len(phaseobs))]
        freeEdges = 1 - np.sum([stoppedEdges[tl][action[tl]].values.squeeze() for tl in range(TL)], axis=0)
        freeEdges = th.FloatTensor(freeEdges).unsqueeze(1)
        obs,_,_,measures = environ.step(action)
        future_cars,phaseobs = obs
        for epoch in range(epochs):
            predicted,embedding = net(g, nids.cuda().to(DEVICE), cars.cuda().to(DEVICE), freeEdges.cuda().to(DEVICE))
            predicted,embedding = net(g, nids.cuda().to(DEVICE), predicted, freeEdges.cuda().to(DEVICE))
            predicted,embedding = net(g, nids.cuda().to(DEVICE), predicted, freeEdges.cuda().to(DEVICE))
            predicted,embedding = net(g, nids.cuda().to(DEVICE), predicted, freeEdges.cuda().to(DEVICE))
            loss = MSE(predicted, th.FloatTensor(future_cars).unsqueeze(1).cuda().to(DEVICE))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            wrong_cars = np.sum(np.abs(predicted.squeeze().squeeze().detach().cpu().numpy() - future_cars))
            cars_total = np.sum(future_cars)
            wrong_cars_adjusted = wrong_cars - (measures['arrived'] + measures['departed'])


            
            if epoch == 0:
                writer.add_scalar("loss", loss.item(), i)
                writer.add_scalar("wrong_cars", wrong_cars, i)
                writer.add_scalar("wrong_cars_adjusted", wrong_cars_adjusted, i)
                writer.add_scalar("wrong_percentage", min(wrong_cars/cars_total,1.0), i)
                writer.add_scalar("total_cars", cars_total, i)
                writer.add_scalar("departed", measures['departed'], i)
                writer.add_scalar("arrived", measures['arrived'], i)

            if epoch == 0 and i%6==0:
                print("Run {:d} | Step {:d} | Epoch {:05d} | Loss {:.4f}".format(run,i,
                            epoch, loss.item()))

        cars = th.FloatTensor(future_cars).unsqueeze(1)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1350: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /usr/local/lib/python3.6/dist-packages/dgl/base.py:18: UserWarning: Initializer is not set. Use zero initializer instead. To suppress this warning, use `set_initializer` to explicitly specify which initializer to use.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: RuntimeWarning: divide by zero encountered in double_scalars
# Run 0 | Step 0 | Epoch 00000 | Loss 0.6685
# Run 0 | Step 6 | Epoch 00000 | Loss 0.5276
# Run 0 | Step 12 | Epoch 00000 | Loss 0.4344
# Run 0 | Step 18 | Epoch 00000 | Loss 0.3458
# Run 0 | Step 24 | Epoch 00000 | Loss 0.2881
# Run 0 | Step 30 | Epoch 00000 | Loss 0.2863
# Run 0 | Step 36 | Epoch 00000 | Loss 0.4074
# Run 0 | Step 42 | Epoch 00000 | Loss 0.2632
# Run 0 | Step 48 | Epoch 00000 | Loss 0.3543
# Run 0 | Step 54 | Epoch 00000 | Loss 0.4656
# Run 0 | Step 60 | Epoch 00000 | Loss 0.3076
# Run 0 | Step 66 | Epoch 00000 | Loss 0.3113
# Run 0 | Step 72 | Epoch 00000 | Loss 0.3411
# Run 0 | Step 78 | Epoch 00000 | Loss 0.3494
# Run 0 | Step 84 | Epoch 00000 | Loss 0.4680
# Run 0 | Step 90 | Epoch 00000 | Loss 0.3491
# Run 0 | Step 96 | Epoch 00000 | Loss 0.5108
# Run 0 | Step 102 | Epoch 00000 | Loss 0.3735
# Run 0 | Step 108 | Epoch 00000 | Loss 0.4207
# Run 0 | Step 114 | Epoch 00000 | Loss 0.3489
# Run 0 | Step 120 | Epoch 00000 | Loss 0.3936
# Run 0 | Step 126 | Epoch 00000 | Loss 0.3779
# Run 0 | Step 132 | Epoch 00000 | Loss 0.4629
# Run 0 | Step 138 | Epoch 00000 | Loss 0.4670
# Run 0 | Step 144 | Epoch 00000 | Loss 0.3351
# Run 0 | Step 150 | Epoch 00000 | Loss 0.4224
# Run 0 | Step 156 | Epoch 00000 | Loss 0.3849
# Run 0 | Step 162 | Epoch 00000 | Loss 0.4464
# Run 0 | Step 168 | Epoch 00000 | Loss 0.3213
# Run 0 | Step 174 | Epoch 00000 | Loss 0.3821
# Run 0 | Step 180 | Epoch 00000 | Loss 0.3607
# Run 0 | Step 186 | Epoch 00000 | Loss 0.3582
# Run 0 | Step 192 | Epoch 00000 | Loss 0.4081
# Run 0 | Step 198 | Epoch 00000 | Loss 0.3641
# Run 0 | Step 204 | Epoch 00000 | Loss 0.4048
# Run 0 | Step 210 | Epoch 00000 | Loss 0.4147
# Run 0 | Step 216 | Epoch 00000 | Loss 0.3065
# Run 0 | Step 222 | Epoch 00000 | Loss 0.3883
# Run 0 | Step 228 | Epoch 00000 | Loss 0.3326
# Run 0 | Step 234 | Epoch 00000 | Loss 0.3949
# Run 0 | Step 240 | Epoch 00000 | Loss 0.4180
# Run 0 | Step 246 | Epoch 00000 | Loss 0.4489
# Run 0 | Step 252 | Epoch 00000 | Loss 0.4232
# Run 0 | Step 258 | Epoch 00000 | Loss 0.3830
# Run 0 | Step 264 | Epoch 00000 | Loss 0.3361
# Run 0 | Step 270 | Epoch 00000 | Loss 0.3077
# Run 0 | Step 276 | Epoch 00000 | Loss 0.2974
# Run 0 | Step 282 | Epoch 00000 | Loss 0.3023
# Run 0 | Step 288 | Epoch 00000 | Loss 0.2951
# Run 0 | Step 294 | Epoch 00000 | Loss 0.4438
# Run 0 | Step 300 | Epoch 00000 | Loss 0.3854
# Run 0 | Step 306 | Epoch 00000 | Loss 0.3166
# Run 0 | Step 312 | Epoch 00000 | Loss 0.3137
# Run 0 | Step 318 | Epoch 00000 | Loss 0.3096
# Run 0 | Step 324 | Epoch 00000 | Loss 0.3174
# Run 0 | Step 330 | Epoch 00000 | Loss 0.4259
# Run 0 | Step 336 | Epoch 00000 | Loss 0.3670
# Run 0 | Step 342 | Epoch 00000 | Loss 0.3054
# Run 0 | Step 348 | Epoch 00000 | Loss 0.3339
# Run 0 | Step 354 | Epoch 00000 | Loss 0.3957
# Run 0 | Step 360 | Epoch 00000 | Loss 0.3193
# Run 0 | Step 366 | Epoch 00000 | Loss 0.3683
# Run 0 | Step 372 | Epoch 00000 | Loss 0.3769
# Run 0 | Step 378 | Epoch 00000 | Loss 0.2792
# Run 0 | Step 384 | Epoch 00000 | Loss 0.3491
# Run 0 | Step 390 | Epoch 00000 | Loss 0.3065
# Run 0 | Step 396 | Epoch 00000 | Loss 0.3106
# Run 0 | Step 402 | Epoch 00000 | Loss 0.3508
# Run 0 | Step 408 | Epoch 00000 | Loss 0.3221
# Run 0 | Step 414 | Epoch 00000 | Loss 0.3313
# Run 0 | Step 420 | Epoch 00000 | Loss 0.2627
# Run 0 | Step 426 | Epoch 00000 | Loss 0.2913
# Run 0 | Step 432 | Epoch 00000 | Loss 0.3043
# Run 0 | Step 438 | Epoch 00000 | Loss 0.2521
# Run 0 | Step 444 | Epoch 00000 | Loss 0.3971
# Run 0 | Step 450 | Epoch 00000 | Loss 0.2788
# Run 0 | Step 456 | Epoch 00000 | Loss 0.3279
# Run 0 | Step 462 | Epoch 00000 | Loss 0.3334
# Run 0 | Step 468 | Epoch 00000 | Loss 0.3741
# Run 0 | Step 474 | Epoch 00000 | Loss 0.3254
# Run 0 | Step 480 | Epoch 00000 | Loss 0.2692
# Run 0 | Step 486 | Epoch 00000 | Loss 0.3045
# Run 0 | Step 492 | Epoch 00000 | Loss 0.2824
# Run 0 | Step 498 | Epoch 00000 | Loss 0.2700
# Run 0 | Step 504 | Epoch 00000 | Loss 0.3517
# Run 0 | Step 510 | Epoch 00000 | Loss 0.2663
# Run 0 | Step 516 | Epoch 00000 | Loss 0.3004
# Run 0 | Step 522 | Epoch 00000 | Loss 0.2856
# Run 0 | Step 528 | Epoch 00000 | Loss 0.2824
# Run 0 | Step 534 | Epoch 00000 | Loss 0.3041
# Run 0 | Step 540 | Epoch 00000 | Loss 0.3043
# Run 0 | Step 546 | Epoch 00000 | Loss 0.3245
# Run 0 | Step 552 | Epoch 00000 | Loss 0.4538
# Run 0 | Step 558 | Epoch 00000 | Loss 0.3597
# Run 0 | Step 564 | Epoch 00000 | Loss 0.4950
# Run 0 | Step 570 | Epoch 00000 | Loss 0.3465
# Run 0 | Step 576 | Epoch 00000 | Loss 0.3479
# Run 0 | Step 582 | Epoch 00000 | Loss 0.4742
# Run 0 | Step 588 | Epoch 00000 | Loss 0.3730
# Run 0 | Step 594 | Epoch 00000 | Loss 0.3456
# Run 0 | Step 600 | Epoch 00000 | Loss 0.2600
# Run 0 | Step 606 | Epoch 00000 | Loss 0.3191
# Run 0 | Step 612 | Epoch 00000 | Loss 0.2973
# Run 0 | Step 618 | Epoch 00000 | Loss 0.3719
# Run 0 | Step 624 | Epoch 00000 | Loss 0.3629
# Run 0 | Step 630 | Epoch 00000 | Loss 0.3359
# Run 0 | Step 636 | Epoch 00000 | Loss 0.3043
# Run 0 | Step 642 | Epoch 00000 | Loss 0.3818
# Run 0 | Step 648 | Epoch 00000 | Loss 0.3851
# Run 0 | Step 654 | Epoch 00000 | Loss 0.4027
# Run 0 | Step 660 | Epoch 00000 | Loss 0.4089
# Run 0 | Step 666 | Epoch 00000 | Loss 0.2774
# Run 0 | Step 672 | Epoch 00000 | Loss 0.2736
# Run 0 | Step 678 | Epoch 00000 | Loss 0.3305
# Run 0 | Step 684 | Epoch 00000 | Loss 0.3457
# Run 0 | Step 690 | Epoch 00000 | Loss 0.2337
# Run 0 | Step 696 | Epoch 00000 | Loss 0.2600
# Run 0 | Step 702 | Epoch 00000 | Loss 0.2698
# Run 0 | Step 708 | Epoch 00000 | Loss 0.3143
# Run 0 | Step 714 | Epoch 00000 | Loss 0.3079
# Run 0 | Step 720 | Epoch 00000 | Loss 0.3011
# Run 0 | Step 726 | Epoch 00000 | Loss 0.4105
# Run 0 | Step 732 | Epoch 00000 | Loss 0.3367
# Run 0 | Step 738 | Epoch 00000 | Loss 0.2497
# Run 0 | Step 744 | Epoch 00000 | Loss 0.2517
# Run 0 | Step 750 | Epoch 00000 | Loss 0.3151
# Run 0 | Step 756 | Epoch 00000 | Loss 0.2973
# Run 0 | Step 762 | Epoch 00000 | Loss 0.3689
# Run 0 | Step 768 | Epoch 00000 | Loss 0.2714
# Run 0 | Step 774 | Epoch 00000 | Loss 0.3062
# Run 0 | Step 780 | Epoch 00000 | Loss 0.5248
# Run 0 | Step 786 | Epoch 00000 | Loss 0.3109
# Run 0 | Step 792 | Epoch 00000 | Loss 0.3831
# Run 0 | Step 798 | Epoch 00000 | Loss 0.3871
# Run 0 | Step 804 | Epoch 00000 | Loss 0.3118
# Run 0 | Step 810 | Epoch 00000 | Loss 0.4322
# Run 0 | Step 816 | Epoch 00000 | Loss 0.3130
# Run 0 | Step 822 | Epoch 00000 | Loss 0.3441
# Run 0 | Step 828 | Epoch 00000 | Loss 0.3292
# Run 0 | Step 834 | Epoch 00000 | Loss 0.3417
# Run 0 | Step 840 | Epoch 00000 | Loss 0.2358
# Run 0 | Step 846 | Epoch 00000 | Loss 0.2141
# Run 0 | Step 852 | Epoch 00000 | Loss 0.2803
# Run 0 | Step 858 | Epoch 00000 | Loss 0.2752
# Run 0 | Step 864 | Epoch 00000 | Loss 0.2796
# Run 0 | Step 870 | Epoch 00000 | Loss 0.2207
# Run 0 | Step 876 | Epoch 00000 | Loss 0.2429
# Run 0 | Step 882 | Epoch 00000 | Loss 0.2447
# Run 0 | Step 888 | Epoch 00000 | Loss 0.3814
# Run 0 | Step 894 | Epoch 00000 | Loss 0.3907
# Run 0 | Step 900 | Epoch 00000 | Loss 0.3195
# Run 0 | Step 906 | Epoch 00000 | Loss 0.3181
# Run 0 | Step 912 | Epoch 00000 | Loss 0.2257
# Run 0 | Step 918 | Epoch 00000 | Loss 0.2626
# Run 0 | Step 924 | Epoch 00000 | Loss 0.1902
# Run 0 | Step 930 | Epoch 00000 | Loss 0.1805
# Run 0 | Step 936 | Epoch 00000 | Loss 0.1836
# Run 0 | Step 942 | Epoch 00000 | Loss 0.1976
# Run 0 | Step 948 | Epoch 00000 | Loss 0.1487
# Run 0 | Step 954 | Epoch 00000 | Loss 0.1743
# Run 0 | Step 960 | Epoch 00000 | Loss 0.2055
# Run 0 | Step 966 | Epoch 00000 | Loss 0.1936
# Run 0 | Step 972 | Epoch 00000 | Loss 0.1596
# Run 0 | Step 978 | Epoch 00000 | Loss 0.1988
# Run 0 | Step 984 | Epoch 00000 | Loss 0.1874
# Run 0 | Step 990 | Epoch 00000 | Loss 0.2298
# Run 0 | Step 996 | Epoch 00000 | Loss 0.2021
# Run 0 | Step 1002 | Epoch 00000 | Loss 0.1625
# Run 0 | Step 1008 | Epoch 00000 | Loss 0.2179
# Run 0 | Step 1014 | Epoch 00000 | Loss 0.2341
# Run 0 | Step 1020 | Epoch 00000 | Loss 0.2082
# Run 0 | Step 1026 | Epoch 00000 | Loss 0.1913
# Run 0 | Step 1032 | Epoch 00000 | Loss 0.1769
# Run 0 | Step 1038 | Epoch 00000 | Loss 0.1533
# Run 0 | Step 1044 | Epoch 00000 | Loss 0.1776
# Run 0 | Step 1050 | Epoch 00000 | Loss 0.1786
# Run 0 | Step 1056 | Epoch 00000 | Loss 0.1552
# Run 0 | Step 1062 | Epoch 00000 | Loss 0.1668
# Run 0 | Step 1068 | Epoch 00000 | Loss 0.1497
# Run 0 | Step 1074 | Epoch 00000 | Loss 0.1771
# Run 0 | Step 1080 | Epoch 00000 | Loss 0.1902
# Run 0 | Step 1086 | Epoch 00000 | Loss 0.1439
# Run 0 | Step 1092 | Epoch 00000 | Loss 0.1590
# Run 0 | Step 1098 | Epoch 00000 | Loss 0.1387
# Run 0 | Step 1104 | Epoch 00000 | Loss 0.1020
# Run 0 | Step 1110 | Epoch 00000 | Loss 0.1091
# Run 0 | Step 1116 | Epoch 00000 | Loss 0.0829
# Run 0 | Step 1122 | Epoch 00000 | Loss 0.0663
# Run 0 | Step 1128 | Epoch 00000 | Loss 0.1126
# Run 0 | Step 1134 | Epoch 00000 | Loss 0.1193
# Run 0 | Step 1140 | Epoch 00000 | Loss 0.0655
# Run 0 | Step 1146 | Epoch 00000 | Loss 0.0769
# Run 0 | Step 1152 | Epoch 00000 | Loss 0.0838
# Run 0 | Step 1158 | Epoch 00000 | Loss 0.0741
# Run 0 | Step 1164 | Epoch 00000 | Loss 0.0987
# Run 0 | Step 1170 | Epoch 00000 | Loss 0.1018
# Run 0 | Step 1176 | Epoch 00000 | Loss 0.0832
# Run 0 | Step 1182 | Epoch 00000 | Loss 0.0837
# Run 0 | Step 1188 | Epoch 00000 | Loss 0.1120
# Run 0 | Step 1194 | Epoch 00000 | Loss 0.0637
# Run 0 | Step 1200 | Epoch 00000 | Loss 0.0720
# Run 0 | Step 1206 | Epoch 00000 | Loss 0.0909
# Run 0 | Step 1212 | Epoch 00000 | Loss 0.0713
# Run 0 | Step 1218 | Epoch 00000 | Loss 0.0783
# Run 0 | Step 1224 | Epoch 00000 | Loss 0.0743
# Run 0 | Step 1230 | Epoch 00000 | Loss 0.0529
# Run 0 | Step 1236 | Epoch 00000 | Loss 0.0647
# Run 0 | Step 1242 | Epoch 00000 | Loss 0.0373
# Run 0 | Step 1248 | Epoch 00000 | Loss 0.0585
# Run 0 | Step 1254 | Epoch 00000 | Loss 0.0389
# Run 0 | Step 1260 | Epoch 00000 | Loss 0.0741
# Run 0 | Step 1266 | Epoch 00000 | Loss 0.0458
# Run 0 | Step 1272 | Epoch 00000 | Loss 0.0112
# Run 0 | Step 1278 | Epoch 00000 | Loss 0.0700
# Run 0 | Step 1284 | Epoch 00000 | Loss 0.0740
# Run 0 | Step 1290 | Epoch 00000 | Loss 0.0655
# Run 0 | Step 1296 | Epoch 00000 | Loss 0.0694
# Run 0 | Step 1302 | Epoch 00000 | Loss 0.0894
# Run 0 | Step 1308 | Epoch 00000 | Loss 0.1474
# Run 0 | Step 1314 | Epoch 00000 | Loss 0.0683
# Run 0 | Step 1320 | Epoch 00000 | Loss 0.0558
# Run 0 | Step 1326 | Epoch 00000 | Loss 0.0717
# Run 0 | Step 1332 | Epoch 00000 | Loss 0.0506
# Run 0 | Step 1338 | Epoch 00000 | Loss 0.0882
# Run 0 | Step 1344 | Epoch 00000 | Loss 0.0520
# Run 0 | Step 1350 | Epoch 00000 | Loss 0.0536
# Run 0 | Step 1356 | Epoch 00000 | Loss 0.1534
# Run 0 | Step 1362 | Epoch 00000 | Loss 0.0753
# Run 0 | Step 1368 | Epoch 00000 | Loss 0.0796
# Run 0 | Step 1374 | Epoch 00000 | Loss 0.0566
# Run 0 | Step 1380 | Epoch 00000 | Loss 0.0361
# Run 0 | Step 1386 | Epoch 00000 | Loss 0.0472
# Run 0 | Step 1392 | Epoch 00000 | Loss 0.0511
# Run 0 | Step 1398 | Epoch 00000 | Loss 0.0526
# Run 0 | Step 1404 | Epoch 00000 | Loss 0.0668
# Run 0 | Step 1410 | Epoch 00000 | Loss 0.1034
# Run 0 | Step 1416 | Epoch 00000 | Loss 0.0520
# Run 0 | Step 1422 | Epoch 00000 | Loss 0.0845
# Run 0 | Step 1428 | Epoch 00000 | Loss 0.1542
# Run 0 | Step 1434 | Epoch 00000 | Loss 0.1010
# Run 0 | Step 1440 | Epoch 00000 | Loss 0.0921
# Run 0 | Step 1446 | Epoch 00000 | Loss 0.0655
# Run 0 | Step 1452 | Epoch 00000 | Loss 0.0708
# Run 0 | Step 1458 | Epoch 00000 | Loss 0.1044
# Run 0 | Step 1464 | Epoch 00000 | Loss 0.0245
# Run 0 | Step 1470 | Epoch 00000 | Loss 0.0485
# Run 0 | Step 1476 | Epoch 00000 | Loss 0.1277
# Run 0 | Step 1482 | Epoch 00000 | Loss 0.0674
# Run 0 | Step 1488 | Epoch 00000 | Loss 0.0718
# Run 0 | Step 1494 | Epoch 00000 | Loss 0.0694
# Run 0 | Step 1500 | Epoch 00000 | Loss 0.0590
# Run 0 | Step 1506 | Epoch 00000 | Loss 0.0749
# Run 0 | Step 1512 | Epoch 00000 | Loss 0.0764
# Run 0 | Step 1518 | Epoch 00000 | Loss 0.0497
# Run 0 | Step 1524 | Epoch 00000 | Loss 0.0616
# Run 0 | Step 1530 | Epoch 00000 | Loss 0.0412
# Run 0 | Step 1536 | Epoch 00000 | Loss 0.0627
# Run 0 | Step 1542 | Epoch 00000 | Loss 0.0527
# Run 0 | Step 1548 | Epoch 00000 | Loss 0.0656
# Run 0 | Step 1554 | Epoch 00000 | Loss 0.0697
# Run 0 | Step 1560 | Epoch 00000 | Loss 0.0566
# Run 0 | Step 1566 | Epoch 00000 | Loss 0.0673
# Run 0 | Step 1572 | Epoch 00000 | Loss 0.0932
# Run 0 | Step 1578 | Epoch 00000 | Loss 0.0531
# Run 0 | Step 1584 | Epoch 00000 | Loss 0.0679
# Run 0 | Step 1590 | Epoch 00000 | Loss 0.0783
# Run 0 | Step 1596 | Epoch 00000 | Loss 0.0505
# Run 0 | Step 1602 | Epoch 00000 | Loss 0.0607
# Run 0 | Step 1608 | Epoch 00000 | Loss 0.0428
# Run 0 | Step 1614 | Epoch 00000 | Loss 0.0495
# Run 0 | Step 1620 | Epoch 00000 | Loss 0.0270
# Run 0 | Step 1626 | Epoch 00000 | Loss 0.0241
# Run 0 | Step 1632 | Epoch 00000 | Loss 0.0572
# Run 0 | Step 1638 | Epoch 00000 | Loss 0.0349
# Run 0 | Step 1644 | Epoch 00000 | Loss 0.0478
# Run 0 | Step 1650 | Epoch 00000 | Loss 0.0323
# Run 0 | Step 1656 | Epoch 00000 | Loss 0.0543
# Run 0 | Step 1662 | Epoch 00000 | Loss 0.0169
# Run 0 | Step 1668 | Epoch 00000 | Loss 0.0094
# Run 0 | Step 1674 | Epoch 00000 | Loss 0.0198
# Run 0 | Step 1680 | Epoch 00000 | Loss 0.0049
# Run 0 | Step 1686 | Epoch 00000 | Loss 0.0050
# Run 0 | Step 1692 | Epoch 00000 | Loss 0.0118
# Run 0 | Step 1698 | Epoch 00000 | Loss 0.0300
# Run 0 | Step 1704 | Epoch 00000 | Loss 0.0324
# Run 0 | Step 1710 | Epoch 00000 | Loss 0.0509
# Run 0 | Step 1716 | Epoch 00000 | Loss 0.0630
# Run 0 | Step 1722 | Epoch 00000 | Loss 0.0584
# Run 0 | Step 1728 | Epoch 00000 | Loss 0.0396
# Run 0 | Step 1734 | Epoch 00000 | Loss 0.0478
# Run 0 | Step 1740 | Epoch 00000 | Loss 0.0466
# Run 0 | Step 1746 | Epoch 00000 | Loss 0.0510
# Run 0 | Step 1752 | Epoch 00000 | Loss 0.0758
# Run 0 | Step 1758 | Epoch 00000 | Loss 0.0494
# Run 0 | Step 1764 | Epoch 00000 | Loss 0.0384
# Run 0 | Step 1770 | Epoch 00000 | Loss 0.0317
# Run 0 | Step 1776 | Epoch 00000 | Loss 0.0746
# Run 0 | Step 1782 | Epoch 00000 | Loss 0.1043
# Run 0 | Step 1788 | Epoch 00000 | Loss 0.0443
# Run 0 | Step 1794 | Epoch 00000 | Loss 0.0648
# Run 0 | Step 1800 | Epoch 00000 | Loss 0.0325
# Run 0 | Step 1806 | Epoch 00000 | Loss 0.0614
# Run 0 | Step 1812 | Epoch 00000 | Loss 0.0473
# Run 0 | Step 1818 | Epoch 00000 | Loss 0.0879
# Run 0 | Step 1824 | Epoch 00000 | Loss 0.0501
# Run 0 | Step 1830 | Epoch 00000 | Loss 0.0266
# Run 0 | Step 1836 | Epoch 00000 | Loss 0.0309
# Run 0 | Step 1842 | Epoch 00000 | Loss 0.0068
# Run 0 | Step 1848 | Epoch 00000 | Loss 0.0138
# Run 0 | Step 1854 | Epoch 00000 | Loss 0.0073
# Run 0 | Step 1860 | Epoch 00000 | Loss 0.0210
# Run 0 | Step 1866 | Epoch 00000 | Loss 0.0200
# Run 0 | Step 1872 | Epoch 00000 | Loss 0.0218
# Run 0 | Step 1878 | Epoch 00000 | Loss 0.0697
# Run 0 | Step 1884 | Epoch 00000 | Loss 0.0765
# Run 0 | Step 1890 | Epoch 00000 | Loss 0.0562
# Run 0 | Step 1896 | Epoch 00000 | Loss 0.0368
# Run 0 | Step 1902 | Epoch 00000 | Loss 0.0755
# Run 0 | Step 1908 | Epoch 00000 | Loss 0.0791
# Run 0 | Step 1914 | Epoch 00000 | Loss 0.0726
# Run 0 | Step 1920 | Epoch 00000 | Loss 0.0852
# Run 0 | Step 1926 | Epoch 00000 | Loss 0.0811
# Run 0 | Step 1932 | Epoch 00000 | Loss 0.0255
# Run 0 | Step 1938 | Epoch 00000 | Loss 0.0195
# Run 0 | Step 1944 | Epoch 00000 | Loss 0.0155
# Run 0 | Step 1950 | Epoch 00000 | Loss 0.0294
# Run 0 | Step 1956 | Epoch 00000 | Loss 0.0305
# Run 0 | Step 1962 | Epoch 00000 | Loss 0.0543
# Run 0 | Step 1968 | Epoch 00000 | Loss 0.0366
# Run 0 | Step 1974 | Epoch 00000 | Loss 0.0433
# Run 0 | Step 1980 | Epoch 00000 | Loss 0.0300
# Run 0 | Step 1986 | Epoch 00000 | Loss 0.0567
# Run 0 | Step 1992 | Epoch 00000 | Loss 0.0675
# Run 0 | Step 1998 | Epoch 00000 | Loss 0.0519
# Run 0 | Step 2004 | Epoch 00000 | Loss 0.0389
# Run 0 | Step 2010 | Epoch 00000 | Loss 0.0499
# Run 0 | Step 2016 | Epoch 00000 | Loss 0.0577
# Run 0 | Step 2022 | Epoch 00000 | Loss 0.0639
# Run 0 | Step 2028 | Epoch 00000 | Loss 0.0624
# Run 0 | Step 2034 | Epoch 00000 | Loss 0.0728
# Run 0 | Step 2040 | Epoch 00000 | Loss 0.0620
# Run 0 | Step 2046 | Epoch 00000 | Loss 0.0898
# Run 0 | Step 2052 | Epoch 00000 | Loss 0.0629
# Run 0 | Step 2058 | Epoch 00000 | Loss 0.0526
# Run 0 | Step 2064 | Epoch 00000 | Loss 0.0828
# Run 0 | Step 2070 | Epoch 00000 | Loss 0.1197
# Run 0 | Step 2076 | Epoch 00000 | Loss 0.0877
# Run 0 | Step 2082 | Epoch 00000 | Loss 0.0677
# Run 0 | Step 2088 | Epoch 00000 | Loss 0.0781
# Run 0 | Step 2094 | Epoch 00000 | Loss 0.0639
# Run 0 | Step 2100 | Epoch 00000 | Loss 0.0825
# Run 0 | Step 2106 | Epoch 00000 | Loss 0.0860
# Run 0 | Step 2112 | Epoch 00000 | Loss 0.0691
# Run 0 | Step 2118 | Epoch 00000 | Loss 0.0811
# Run 0 | Step 2124 | Epoch 00000 | Loss 0.0884
# Run 0 | Step 2130 | Epoch 00000 | Loss 0.0542
# Run 0 | Step 2136 | Epoch 00000 | Loss 0.0732
# Run 0 | Step 2142 | Epoch 00000 | Loss 0.1088
# Run 0 | Step 2148 | Epoch 00000 | Loss 0.0706
# Run 0 | Step 2154 | Epoch 00000 | Loss 0.0852
# Run 0 | Step 2160 | Epoch 00000 | Loss 0.0826
# Run 0 | Step 2166 | Epoch 00000 | Loss 0.0962
# Run 0 | Step 2172 | Epoch 00000 | Loss 0.1476
# Run 0 | Step 2178 | Epoch 00000 | Loss 0.0977
# Run 0 | Step 2184 | Epoch 00000 | Loss 0.1032
# Run 0 | Step 2190 | Epoch 00000 | Loss 0.1083
# Run 0 | Step 2196 | Epoch 00000 | Loss 0.1221
# Run 0 | Step 2202 | Epoch 00000 | Loss 0.1671
# Run 0 | Step 2208 | Epoch 00000 | Loss 0.0997
# Run 0 | Step 2214 | Epoch 00000 | Loss 0.1150
# Run 0 | Step 2220 | Epoch 00000 | Loss 0.0955
# Run 0 | Step 2226 | Epoch 00000 | Loss 0.0893
# Run 0 | Step 2232 | Epoch 00000 | Loss 0.0937
# Run 0 | Step 2238 | Epoch 00000 | Loss 0.1326
# Run 0 | Step 2244 | Epoch 00000 | Loss 0.1339
# Run 0 | Step 2250 | Epoch 00000 | Loss 0.1965
# Run 0 | Step 2256 | Epoch 00000 | Loss 0.1207
# Run 0 | Step 2262 | Epoch 00000 | Loss 0.1207
# Run 0 | Step 2268 | Epoch 00000 | Loss 0.1091
# Run 0 | Step 2274 | Epoch 00000 | Loss 0.1391
# Run 0 | Step 2280 | Epoch 00000 | Loss 0.1303
# Run 0 | Step 2286 | Epoch 00000 | Loss 0.1522
# Run 0 | Step 2292 | Epoch 00000 | Loss 0.1046
# Run 0 | Step 2298 | Epoch 00000 | Loss 0.1223
# Run 0 | Step 2304 | Epoch 00000 | Loss 0.1063
# Run 0 | Step 2310 | Epoch 00000 | Loss 0.1249
# Run 0 | Step 2316 | Epoch 00000 | Loss 0.1021
# Run 0 | Step 2322 | Epoch 00000 | Loss 0.1203
# Run 0 | Step 2328 | Epoch 00000 | Loss 0.0812
# Run 0 | Step 2334 | Epoch 00000 | Loss 0.1517
# Run 0 | Step 2340 | Epoch 00000 | Loss 0.1630
# Run 0 | Step 2346 | Epoch 00000 | Loss 0.1571
# Run 0 | Step 2352 | Epoch 00000 | Loss 0.1362
# Run 0 | Step 2358 | Epoch 00000 | Loss 0.1505
# Run 0 | Step 2364 | Epoch 00000 | Loss 0.1990
# Run 0 | Step 2370 | Epoch 00000 | Loss 0.1909
# Run 0 | Step 2376 | Epoch 00000 | Loss 0.2174
# Run 0 | Step 2382 | Epoch 00000 | Loss 0.1729
# Run 0 | Step 2388 | Epoch 00000 | Loss 0.1270
# Run 0 | Step 2394 | Epoch 00000 | Loss 0.1183
# Run 0 | Step 2400 | Epoch 00000 | Loss 0.1083
# Run 0 | Step 2406 | Epoch 00000 | Loss 0.1122
# Run 0 | Step 2412 | Epoch 00000 | Loss 0.1102
# Run 0 | Step 2418 | Epoch 00000 | Loss 0.1319
# Run 0 | Step 2424 | Epoch 00000 | Loss 0.1237
# Run 0 | Step 2430 | Epoch 00000 | Loss 0.1656
# Run 0 | Step 2436 | Epoch 00000 | Loss 0.2012
# Run 0 | Step 2442 | Epoch 00000 | Loss 0.2321
# Run 0 | Step 2448 | Epoch 00000 | Loss 0.0872
# Run 0 | Step 2454 | Epoch 00000 | Loss 0.1917
# Run 0 | Step 2460 | Epoch 00000 | Loss 0.1411
# Run 0 | Step 2466 | Epoch 00000 | Loss 0.1085
# Run 0 | Step 2472 | Epoch 00000 | Loss 0.1255
# Run 0 | Step 2478 | Epoch 00000 | Loss 0.0626
# Run 0 | Step 2484 | Epoch 00000 | Loss 0.1163
# Run 0 | Step 2490 | Epoch 00000 | Loss 0.1563
# Run 0 | Step 2496 | Epoch 00000 | Loss 0.1296
# Run 0 | Step 2502 | Epoch 00000 | Loss 0.1438
# Run 0 | Step 2508 | Epoch 00000 | Loss 0.1288
# Run 0 | Step 2514 | Epoch 00000 | Loss 0.1273
# Run 0 | Step 2520 | Epoch 00000 | Loss 0.0859
# Run 0 | Step 2526 | Epoch 00000 | Loss 0.1345
# Run 0 | Step 2532 | Epoch 00000 | Loss 0.1470
# Run 0 | Step 2538 | Epoch 00000 | Loss 0.0995
# Run 0 | Step 2544 | Epoch 00000 | Loss 0.1351
# Run 0 | Step 2550 | Epoch 00000 | Loss 0.1606
# Run 0 | Step 2556 | Epoch 00000 | Loss 0.1248
# Run 0 | Step 2562 | Epoch 00000 | Loss 0.1005
# Run 0 | Step 2568 | Epoch 00000 | Loss 0.0897
# Run 0 | Step 2574 | Epoch 00000 | Loss 0.1222
# Run 0 | Step 2580 | Epoch 00000 | Loss 0.1059
# Run 0 | Step 2586 | Epoch 00000 | Loss 0.1153
# Run 0 | Step 2592 | Epoch 00000 | Loss 0.1493
# Run 0 | Step 2598 | Epoch 00000 | Loss 0.1254
# Run 0 | Step 2604 | Epoch 00000 | Loss 0.1995
# Run 0 | Step 2610 | Epoch 00000 | Loss 0.2146
# Run 0 | Step 2616 | Epoch 00000 | Loss 0.1782
# Run 0 | Step 2622 | Epoch 00000 | Loss 0.1367
# Run 0 | Step 2628 | Epoch 00000 | Loss 0.1724
# Run 0 | Step 2634 | Epoch 00000 | Loss 0.1745
# Run 0 | Step 2640 | Epoch 00000 | Loss 0.1160
# Run 0 | Step 2646 | Epoch 00000 | Loss 0.1494
# Run 0 | Step 2652 | Epoch 00000 | Loss 0.0739
# Run 0 | Step 2658 | Epoch 00000 | Loss 0.1088
# Run 0 | Step 2664 | Epoch 00000 | Loss 0.1225
# Run 0 | Step 2670 | Epoch 00000 | Loss 0.1842
# Run 0 | Step 2676 | Epoch 00000 | Loss 0.0962
# Run 0 | Step 2682 | Epoch 00000 | Loss 0.1315
# Run 0 | Step 2688 | Epoch 00000 | Loss 0.1368
# Run 0 | Step 2694 | Epoch 00000 | Loss 0.1178
# Run 0 | Step 2700 | Epoch 00000 | Loss 0.1349
# Run 0 | Step 2706 | Epoch 00000 | Loss 0.1251
# Run 0 | Step 2712 | Epoch 00000 | Loss 0.1042
# Run 0 | Step 2718 | Epoch 00000 | Loss 0.0979
# Run 0 | Step 2724 | Epoch 00000 | Loss 0.1553
# Run 0 | Step 2730 | Epoch 00000 | Loss 0.1628
# Run 0 | Step 2736 | Epoch 00000 | Loss 0.1303
# Run 0 | Step 2742 | Epoch 00000 | Loss 0.1115
# Run 0 | Step 2748 | Epoch 00000 | Loss 0.1002
# Run 0 | Step 2754 | Epoch 00000 | Loss 0.1270
# Run 0 | Step 2760 | Epoch 00000 | Loss 0.0876
# Run 0 | Step 2766 | Epoch 00000 | Loss 0.0883
# Run 0 | Step 2772 | Epoch 00000 | Loss 0.1137
# Run 0 | Step 2778 | Epoch 00000 | Loss 0.0829
# Run 0 | Step 2784 | Epoch 00000 | Loss 0.0948
# Run 0 | Step 2790 | Epoch 00000 | Loss 0.0780
# Run 0 | Step 2796 | Epoch 00000 | Loss 0.0606
# Run 0 | Step 2802 | Epoch 00000 | Loss 0.1249
# Run 0 | Step 2808 | Epoch 00000 | Loss 0.1574
# Run 0 | Step 2814 | Epoch 00000 | Loss 0.0849
# Run 0 | Step 2820 | Epoch 00000 | Loss 0.0914
# Run 0 | Step 2826 | Epoch 00000 | Loss 0.0758
# Run 0 | Step 2832 | Epoch 00000 | Loss 0.1213
# Run 0 | Step 2838 | Epoch 00000 | Loss 0.0987
# Run 0 | Step 2844 | Epoch 00000 | Loss 0.1117
# Run 0 | Step 2850 | Epoch 00000 | Loss 0.0984
# Run 0 | Step 2856 | Epoch 00000 | Loss 0.1743
# Run 0 | Step 2862 | Epoch 00000 | Loss 0.1308
# Run 0 | Step 2868 | Epoch 00000 | Loss 0.0908
# Run 0 | Step 2874 | Epoch 00000 | Loss 0.1117
# Run 0 | Step 2880 | Epoch 00000 | Loss 0.1311
# Run 0 | Step 2886 | Epoch 00000 | Loss 0.1162
# Run 0 | Step 2892 | Epoch 00000 | Loss 0.0834
# Run 0 | Step 2898 | Epoch 00000 | Loss 0.1229
# Run 0 | Step 2904 | Epoch 00000 | Loss 0.0925
# Run 0 | Step 2910 | Epoch 00000 | Loss 0.1105
# Run 0 | Step 2916 | Epoch 00000 | Loss 0.0948
# Run 0 | Step 2922 | Epoch 00000 | Loss 0.1515
# Run 0 | Step 2928 | Epoch 00000 | Loss 0.1040
# Run 0 | Step 2934 | Epoch 00000 | Loss 0.1467
# Run 0 | Step 2940 | Epoch 00000 | Loss 0.2240
# Run 0 | Step 2946 | Epoch 00000 | Loss 0.1174
# Run 0 | Step 2952 | Epoch 00000 | Loss 0.1018
# Run 0 | Step 2958 | Epoch 00000 | Loss 0.1251
# Run 0 | Step 2964 | Epoch 00000 | Loss 0.0997
# Run 0 | Step 2970 | Epoch 00000 | Loss 0.1455
# Run 0 | Step 2976 | Epoch 00000 | Loss 0.1493
# Run 0 | Step 2982 | Epoch 00000 | Loss 0.1613
# Run 0 | Step 2988 | Epoch 00000 | Loss 0.1803
# Run 0 | Step 2994 | Epoch 00000 | Loss 0.1479
# Run 0 | Step 3000 | Epoch 00000 | Loss 0.2080
# Run 0 | Step 3006 | Epoch 00000 | Loss 0.1555
# Run 0 | Step 3012 | Epoch 00000 | Loss 0.1371
# Run 0 | Step 3018 | Epoch 00000 | Loss 0.1564
# Run 0 | Step 3024 | Epoch 00000 | Loss 0.0879
# Run 0 | Step 3030 | Epoch 00000 | Loss 0.0993
# Run 0 | Step 3036 | Epoch 00000 | Loss 0.1499
# Run 0 | Step 3042 | Epoch 00000 | Loss 0.1503
# Run 0 | Step 3048 | Epoch 00000 | Loss 0.1431
# Run 0 | Step 3054 | Epoch 00000 | Loss 0.0940
# Run 0 | Step 3060 | Epoch 00000 | Loss 0.0687
# Run 0 | Step 3066 | Epoch 00000 | Loss 0.0960
# Run 0 | Step 3072 | Epoch 00000 | Loss 0.1069
# Run 0 | Step 3078 | Epoch 00000 | Loss 0.1516
# Run 0 | Step 3084 | Epoch 00000 | Loss 0.1679
# Run 0 | Step 3090 | Epoch 00000 | Loss 0.1241
# Run 0 | Step 3096 | Epoch 00000 | Loss 0.1143
# Run 0 | Step 3102 | Epoch 00000 | Loss 0.0951
# Run 0 | Step 3108 | Epoch 00000 | Loss 0.0933
# Run 0 | Step 3114 | Epoch 00000 | Loss 0.0806
# Run 0 | Step 3120 | Epoch 00000 | Loss 0.0906
# Run 0 | Step 3126 | Epoch 00000 | Loss 0.1146
# Run 0 | Step 3132 | Epoch 00000 | Loss 0.1002
# Run 0 | Step 3138 | Epoch 00000 | Loss 0.1169
# Run 0 | Step 3144 | Epoch 00000 | Loss 0.0736
# Run 0 | Step 3150 | Epoch 00000 | Loss 0.0752
# Run 0 | Step 3156 | Epoch 00000 | Loss 0.0949
# Run 0 | Step 3162 | Epoch 00000 | Loss 0.0681
# Run 0 | Step 3168 | Epoch 00000 | Loss 0.1402
# Run 0 | Step 3174 | Epoch 00000 | Loss 0.0977
# Run 0 | Step 3180 | Epoch 00000 | Loss 0.1419
# Run 0 | Step 3186 | Epoch 00000 | Loss 0.1285
# Run 0 | Step 3192 | Epoch 00000 | Loss 0.1355
# Run 0 | Step 3198 | Epoch 00000 | Loss 0.1462
# Run 0 | Step 3204 | Epoch 00000 | Loss 0.2087
# Run 0 | Step 3210 | Epoch 00000 | Loss 0.1315
# Run 0 | Step 3216 | Epoch 00000 | Loss 0.1849
# Run 0 | Step 3222 | Epoch 00000 | Loss 0.1357
# Run 0 | Step 3228 | Epoch 00000 | Loss 0.0953
# Run 0 | Step 3234 | Epoch 00000 | Loss 0.1115
# Run 0 | Step 3240 | Epoch 00000 | Loss 0.1259
# Run 0 | Step 3246 | Epoch 00000 | Loss 0.1441
# Run 0 | Step 3252 | Epoch 00000 | Loss 0.1490
# Run 0 | Step 3258 | Epoch 00000 | Loss 0.1702
# Run 0 | Step 3264 | Epoch 00000 | Loss 0.1091
# Run 0 | Step 3270 | Epoch 00000 | Loss 0.1321
# Run 0 | Step 3276 | Epoch 00000 | Loss 0.0976
# Run 0 | Step 3282 | Epoch 00000 | Loss 0.1275
# Run 0 | Step 3288 | Epoch 00000 | Loss 0.0619
# Run 0 | Step 3294 | Epoch 00000 | Loss 0.1642
# Run 0 | Step 3300 | Epoch 00000 | Loss 0.0996
# Run 0 | Step 3306 | Epoch 00000 | Loss 0.0904
# Run 0 | Step 3312 | Epoch 00000 | Loss 0.0936
# Run 0 | Step 3318 | Epoch 00000 | Loss 0.1301
# Run 0 | Step 3324 | Epoch 00000 | Loss 0.1304
# Run 0 | Step 3330 | Epoch 00000 | Loss 0.1550
# Run 0 | Step 3336 | Epoch 00000 | Loss 0.1114
# Run 0 | Step 3342 | Epoch 00000 | Loss 0.1751
# Run 0 | Step 3348 | Epoch 00000 | Loss 0.1258
# Run 0 | Step 3354 | Epoch 00000 | Loss 0.1195
# Run 0 | Step 3360 | Epoch 00000 | Loss 0.1000
# Run 0 | Step 3366 | Epoch 00000 | Loss 0.1269
# Run 0 | Step 3372 | Epoch 00000 | Loss 0.0926
# Run 0 | Step 3378 | Epoch 00000 | Loss 0.0845
# Run 0 | Step 3384 | Epoch 00000 | Loss 0.0832
# Run 0 | Step 3390 | Epoch 00000 | Loss 0.1576
# Run 0 | Step 3396 | Epoch 00000 | Loss 0.1220
# Run 0 | Step 3402 | Epoch 00000 | Loss 0.1080
# Run 0 | Step 3408 | Epoch 00000 | Loss 0.0908
# Run 0 | Step 3414 | Epoch 00000 | Loss 0.1181
# Run 0 | Step 3420 | Epoch 00000 | Loss 0.1169
# Run 0 | Step 3426 | Epoch 00000 | Loss 0.1184
# Run 0 | Step 3432 | Epoch 00000 | Loss 0.1733
# Run 0 | Step 3438 | Epoch 00000 | Loss 0.1240
# Run 0 | Step 3444 | Epoch 00000 | Loss 0.1680
# Run 0 | Step 3450 | Epoch 00000 | Loss 0.1894
# Run 0 | Step 3456 | Epoch 00000 | Loss 0.1012
# Run 0 | Step 3462 | Epoch 00000 | Loss 0.1142
# Run 0 | Step 3468 | Epoch 00000 | Loss 0.1299
# Run 0 | Step 3474 | Epoch 00000 | Loss 0.1474
# Run 0 | Step 3480 | Epoch 00000 | Loss 0.1691
# Run 0 | Step 3486 | Epoch 00000 | Loss 0.1108
# Run 0 | Step 3492 | Epoch 00000 | Loss 0.1407
# Run 0 | Step 3498 | Epoch 00000 | Loss 0.1323
# Run 0 | Step 3504 | Epoch 00000 | Loss 0.1712
# Run 0 | Step 3510 | Epoch 00000 | Loss 0.1272
# Run 0 | Step 3516 | Epoch 00000 | Loss 0.1727
# Run 0 | Step 3522 | Epoch 00000 | Loss 0.1730
# Run 0 | Step 3528 | Epoch 00000 | Loss 0.2623
# Run 0 | Step 3534 | Epoch 00000 | Loss 0.2211
# Run 0 | Step 3540 | Epoch 00000 | Loss 0.1808
# Run 0 | Step 3546 | Epoch 00000 | Loss 0.1593
# Run 0 | Step 3552 | Epoch 00000 | Loss 0.1244
# Run 0 | Step 3558 | Epoch 00000 | Loss 0.1011
# Run 0 | Step 3564 | Epoch 00000 | Loss 0.1355
# Run 0 | Step 3570 | Epoch 00000 | Loss 0.1847
# Run 0 | Step 3576 | Epoch 00000 | Loss 0.1297
# Run 0 | Step 3582 | Epoch 00000 | Loss 0.1363
# Run 0 | Step 3588 | Epoch 00000 | Loss 0.1099
# Run 0 | Step 3594 | Epoch 00000 | Loss 0.1610
# Run 0 | Step 3600 | Epoch 00000 | Loss 0.2020
# Run 0 | Step 3606 | Epoch 00000 | Loss 0.1760
# Run 0 | Step 3612 | Epoch 00000 | Loss 0.1618
# Run 0 | Step 3618 | Epoch 00000 | Loss 0.2029
# Run 0 | Step 3624 | Epoch 00000 | Loss 0.1288
# Run 0 | Step 3630 | Epoch 00000 | Loss 0.1248
# Run 0 | Step 3636 | Epoch 00000 | Loss 0.1476
# Run 0 | Step 3642 | Epoch 00000 | Loss 0.1305
# Run 0 | Step 3648 | Epoch 00000 | Loss 0.1795
# Run 0 | Step 3654 | Epoch 00000 | Loss 0.1048
# Run 0 | Step 3660 | Epoch 00000 | Loss 0.0594
# Run 0 | Step 3666 | Epoch 00000 | Loss 0.0747
# Run 0 | Step 3672 | Epoch 00000 | Loss 0.1364
# Run 0 | Step 3678 | Epoch 00000 | Loss 0.0881
# Run 0 | Step 3684 | Epoch 00000 | Loss 0.0653
# Run 0 | Step 3690 | Epoch 00000 | Loss 0.0711
# Run 0 | Step 3696 | Epoch 00000 | Loss 0.0982
# Run 0 | Step 3702 | Epoch 00000 | Loss 0.1135
# Run 0 | Step 3708 | Epoch 00000 | Loss 0.1904
# Run 0 | Step 3714 | Epoch 00000 | Loss 0.1351
# Run 0 | Step 3720 | Epoch 00000 | Loss 0.1017
# Run 0 | Step 3726 | Epoch 00000 | Loss 0.1315
# Run 0 | Step 3732 | Epoch 00000 | Loss 0.2146
# Run 0 | Step 3738 | Epoch 00000 | Loss 0.1367
# Run 0 | Step 3744 | Epoch 00000 | Loss 0.1942
# Run 0 | Step 3750 | Epoch 00000 | Loss 0.2541
# Run 0 | Step 3756 | Epoch 00000 | Loss 0.2362
# Run 0 | Step 3762 | Epoch 00000 | Loss 0.1855
# Run 0 | Step 3768 | Epoch 00000 | Loss 0.1168
# Run 0 | Step 3774 | Epoch 00000 | Loss 0.1030
# Run 0 | Step 3780 | Epoch 00000 | Loss 0.1160
# Run 0 | Step 3786 | Epoch 00000 | Loss 0.1078
# Run 0 | Step 3792 | Epoch 00000 | Loss 0.0876
# Run 0 | Step 3798 | Epoch 00000 | Loss 0.1060
# Run 0 | Step 3804 | Epoch 00000 | Loss 0.1396
# Run 0 | Step 3810 | Epoch 00000 | Loss 0.1272
# Run 0 | Step 3816 | Epoch 00000 | Loss 0.1259
# Run 0 | Step 3822 | Epoch 00000 | Loss 0.1326
# Run 0 | Step 3828 | Epoch 00000 | Loss 0.1337
# Run 0 | Step 3834 | Epoch 00000 | Loss 0.2276
# Run 0 | Step 3840 | Epoch 00000 | Loss 0.1210
# Run 0 | Step 3846 | Epoch 00000 | Loss 0.1752
# Run 0 | Step 3852 | Epoch 00000 | Loss 0.1738
# Run 0 | Step 3858 | Epoch 00000 | Loss 0.1562
# Run 0 | Step 3864 | Epoch 00000 | Loss 0.1683
# Run 0 | Step 3870 | Epoch 00000 | Loss 0.1241
# Run 0 | Step 3876 | Epoch 00000 | Loss 0.1626
# Run 0 | Step 3882 | Epoch 00000 | Loss 0.1726
# Run 0 | Step 3888 | Epoch 00000 | Loss 0.1705
# Run 0 | Step 3894 | Epoch 00000 | Loss 0.1290
# Run 0 | Step 3900 | Epoch 00000 | Loss 0.1249
# Run 0 | Step 3906 | Epoch 00000 | Loss 0.1531
# Run 0 | Step 3912 | Epoch 00000 | Loss 0.1778
# Run 0 | Step 3918 | Epoch 00000 | Loss 0.1599
# Run 0 | Step 3924 | Epoch 00000 | Loss 0.1812
# Run 0 | Step 3930 | Epoch 00000 | Loss 0.1280
# Run 0 | Step 3936 | Epoch 00000 | Loss 0.1766
# Run 0 | Step 3942 | Epoch 00000 | Loss 0.1540
# Run 0 | Step 3948 | Epoch 00000 | Loss 0.1798
# Run 0 | Step 3954 | Epoch 00000 | Loss 0.1470
# Run 0 | Step 3960 | Epoch 00000 | Loss 0.1192
# Run 0 | Step 3966 | Epoch 00000 | Loss 0.0879
# Run 0 | Step 3972 | Epoch 00000 | Loss 0.1515
# Run 0 | Step 3978 | Epoch 00000 | Loss 0.1322
# Run 0 | Step 3984 | Epoch 00000 | Loss 0.1760
# Run 0 | Step 3990 | Epoch 00000 | Loss 0.1392
# Run 0 | Step 3996 | Epoch 00000 | Loss 0.1213
# Run 0 | Step 4002 | Epoch 00000 | Loss 0.1321
# Run 0 | Step 4008 | Epoch 00000 | Loss 0.1534
# Run 0 | Step 4014 | Epoch 00000 | Loss 0.0952
# Run 0 | Step 4020 | Epoch 00000 | Loss 0.1300
# Run 0 | Step 4026 | Epoch 00000 | Loss 0.1230
# Run 0 | Step 4032 | Epoch 00000 | Loss 0.0921
# Run 0 | Step 4038 | Epoch 00000 | Loss 0.1010
# Run 0 | Step 4044 | Epoch 00000 | Loss 0.1413
# Run 0 | Step 4050 | Epoch 00000 | Loss 0.1161
# Run 0 | Step 4056 | Epoch 00000 | Loss 0.1230
# Run 0 | Step 4062 | Epoch 00000 | Loss 0.1386
# Run 0 | Step 4068 | Epoch 00000 | Loss 0.1427
# Run 0 | Step 4074 | Epoch 00000 | Loss 0.1415
# Run 0 | Step 4080 | Epoch 00000 | Loss 0.1646
# Run 0 | Step 4086 | Epoch 00000 | Loss 0.1314
# Run 0 | Step 4092 | Epoch 00000 | Loss 0.1378
# Run 0 | Step 4098 | Epoch 00000 | Loss 0.1511
# Run 0 | Step 4104 | Epoch 00000 | Loss 0.0916
# Run 0 | Step 4110 | Epoch 00000 | Loss 0.1317
# Run 0 | Step 4116 | Epoch 00000 | Loss 0.1100
# Run 0 | Step 4122 | Epoch 00000 | Loss 0.1052
# Run 0 | Step 4128 | Epoch 00000 | Loss 0.1497
# Run 0 | Step 4134 | Epoch 00000 | Loss 0.1305
# Run 0 | Step 4140 | Epoch 00000 | Loss 0.1412
# Run 0 | Step 4146 | Epoch 00000 | Loss 0.1097
# Run 0 | Step 4152 | Epoch 00000 | Loss 0.2437
# Run 0 | Step 4158 | Epoch 00000 | Loss 0.1443
# Run 0 | Step 4164 | Epoch 00000 | Loss 0.1998
# Run 0 | Step 4170 | Epoch 00000 | Loss 0.1751
# Run 0 | Step 4176 | Epoch 00000 | Loss 0.1369
# Run 0 | Step 4182 | Epoch 00000 | Loss 0.1912
# Run 0 | Step 4188 | Epoch 00000 | Loss 0.1472
# Run 0 | Step 4194 | Epoch 00000 | Loss 0.1334
# Run 0 | Step 4200 | Epoch 00000 | Loss 0.1443
# Run 0 | Step 4206 | Epoch 00000 | Loss 0.1301
# Run 0 | Step 4212 | Epoch 00000 | Loss 0.1258
# Run 0 | Step 4218 | Epoch 00000 | Loss 0.1605
# Run 0 | Step 4224 | Epoch 00000 | Loss 0.1814
# Run 0 | Step 4230 | Epoch 00000 | Loss 0.1460
# Run 0 | Step 4236 | Epoch 00000 | Loss 0.1737
# Run 0 | Step 4242 | Epoch 00000 | Loss 0.1605
# Run 0 | Step 4248 | Epoch 00000 | Loss 0.1392
# Run 0 | Step 4254 | Epoch 00000 | Loss 0.3235
# Run 0 | Step 4260 | Epoch 00000 | Loss 0.2053
# Run 0 | Step 4266 | Epoch 00000 | Loss 0.1631
# Run 0 | Step 4272 | Epoch 00000 | Loss 0.1872
# Run 0 | Step 4278 | Epoch 00000 | Loss 0.1897
# Run 0 | Step 4284 | Epoch 00000 | Loss 0.1500
# Run 0 | Step 4290 | Epoch 00000 | Loss 0.2018
# Run 0 | Step 4296 | Epoch 00000 | Loss 0.1860
# Run 0 | Step 4302 | Epoch 00000 | Loss 0.2225
# Run 0 | Step 4308 | Epoch 00000 | Loss 0.1729
# Run 0 | Step 4314 | Epoch 00000 | Loss 0.1716
# Run 0 | Step 4320 | Epoch 00000 | Loss 0.2192
# Run 0 | Step 4326 | Epoch 00000 | Loss 0.1839
# Run 0 | Step 4332 | Epoch 00000 | Loss 0.2395
# Run 0 | Step 4338 | Epoch 00000 | Loss 0.2294
# Run 0 | Step 4344 | Epoch 00000 | Loss 0.1998
# Run 0 | Step 4350 | Epoch 00000 | Loss 0.2664
# Run 0 | Step 4356 | Epoch 00000 | Loss 0.1826
# Run 0 | Step 4362 | Epoch 00000 | Loss 0.1978
# Run 0 | Step 4368 | Epoch 00000 | Loss 0.2334
# Run 0 | Step 4374 | Epoch 00000 | Loss 0.2016
# Run 0 | Step 4380 | Epoch 00000 | Loss 0.2023
# Run 0 | Step 4386 | Epoch 00000 | Loss 0.1812
# Run 0 | Step 4392 | Epoch 00000 | Loss 0.1949
# Run 0 | Step 4398 | Epoch 00000 | Loss 0.2153
# Run 0 | Step 4404 | Epoch 00000 | Loss 0.2551
# Run 0 | Step 4410 | Epoch 00000 | Loss 0.3101
# Run 0 | Step 4416 | Epoch 00000 | Loss 0.2400
# Run 0 | Step 4422 | Epoch 00000 | Loss 0.2629
# Run 0 | Step 4428 | Epoch 00000 | Loss 0.2082
# Run 0 | Step 4434 | Epoch 00000 | Loss 0.2688
# Run 0 | Step 4440 | Epoch 00000 | Loss 0.1645
# Run 0 | Step 4446 | Epoch 00000 | Loss 0.1561
# Run 0 | Step 4452 | Epoch 00000 | Loss 0.1986
# Run 0 | Step 4458 | Epoch 00000 | Loss 0.1337
# Run 0 | Step 4464 | Epoch 00000 | Loss 0.2028
# Run 0 | Step 4470 | Epoch 00000 | Loss 0.2389
# Run 0 | Step 4476 | Epoch 00000 | Loss 0.2197
# Run 0 | Step 4482 | Epoch 00000 | Loss 0.1729
# Run 0 | Step 4488 | Epoch 00000 | Loss 0.1672
# Run 0 | Step 4494 | Epoch 00000 | Loss 0.2071
# Run 0 | Step 4500 | Epoch 00000 | Loss 0.1910
# Run 0 | Step 4506 | Epoch 00000 | Loss 0.1708
# Run 0 | Step 4512 | Epoch 00000 | Loss 0.2092
# Run 0 | Step 4518 | Epoch 00000 | Loss 0.2165
# Run 0 | Step 4524 | Epoch 00000 | Loss 0.2000
# Run 0 | Step 4530 | Epoch 00000 | Loss 0.1779
# Run 0 | Step 4536 | Epoch 00000 | Loss 0.2579
# Run 0 | Step 4542 | Epoch 00000 | Loss 0.2037
# Run 0 | Step 4548 | Epoch 00000 | Loss 0.1592
# Run 0 | Step 4554 | Epoch 00000 | Loss 0.1634
# Run 0 | Step 4560 | Epoch 00000 | Loss 0.1326
# Run 0 | Step 4566 | Epoch 00000 | Loss 0.1507
# Run 0 | Step 4572 | Epoch 00000 | Loss 0.1659
# Run 0 | Step 4578 | Epoch 00000 | Loss 0.1406
# Run 0 | Step 4584 | Epoch 00000 | Loss 0.1135
# Run 0 | Step 4590 | Epoch 00000 | Loss 0.1122
# Run 0 | Step 4596 | Epoch 00000 | Loss 0.1698
# Run 0 | Step 4602 | Epoch 00000 | Loss 0.1473
# Run 0 | Step 4608 | Epoch 00000 | Loss 0.1692
# Run 0 | Step 4614 | Epoch 00000 | Loss 0.1962
# Run 0 | Step 4620 | Epoch 00000 | Loss 0.1808
# Run 0 | Step 4626 | Epoch 00000 | Loss 0.2161
# Run 0 | Step 4632 | Epoch 00000 | Loss 0.1792
# Run 0 | Step 4638 | Epoch 00000 | Loss 0.1832
# Run 0 | Step 4644 | Epoch 00000 | Loss 0.2545
# Run 0 | Step 4650 | Epoch 00000 | Loss 0.1878
# Run 0 | Step 4656 | Epoch 00000 | Loss 0.1395
# Run 0 | Step 4662 | Epoch 00000 | Loss 0.2110
# Run 0 | Step 4668 | Epoch 00000 | Loss 0.1603
# Run 0 | Step 4674 | Epoch 00000 | Loss 0.1747
# Run 0 | Step 4680 | Epoch 00000 | Loss 0.1781
# Run 0 | Step 4686 | Epoch 00000 | Loss 0.1817
# Run 0 | Step 4692 | Epoch 00000 | Loss 0.1644
# Run 0 | Step 4698 | Epoch 00000 | Loss 0.1716
# Run 0 | Step 4704 | Epoch 00000 | Loss 0.1308
# Run 0 | Step 4710 | Epoch 00000 | Loss 0.1590
# Run 0 | Step 4716 | Epoch 00000 | Loss 0.1267
# Run 0 | Step 4722 | Epoch 00000 | Loss 0.1327
# Run 0 | Step 4728 | Epoch 00000 | Loss 0.1067
# Run 0 | Step 4734 | Epoch 00000 | Loss 0.1986
# Run 0 | Step 4740 | Epoch 00000 | Loss 0.1366
# Run 0 | Step 4746 | Epoch 00000 | Loss 0.1593
# Run 0 | Step 4752 | Epoch 00000 | Loss 0.1403
# Run 0 | Step 4758 | Epoch 00000 | Loss 0.2447
# Run 0 | Step 4764 | Epoch 00000 | Loss 0.1642
# Run 0 | Step 4770 | Epoch 00000 | Loss 0.2286
# Run 0 | Step 4776 | Epoch 00000 | Loss 0.1731
# Run 0 | Step 4782 | Epoch 00000 | Loss 0.2464
# Run 0 | Step 4788 | Epoch 00000 | Loss 0.2060
# Run 0 | Step 4794 | Epoch 00000 | Loss 0.1667
# Run 0 | Step 4800 | Epoch 00000 | Loss 0.2412
# Run 0 | Step 4806 | Epoch 00000 | Loss 0.2298
# Run 0 | Step 4812 | Epoch 00000 | Loss 0.1652
# Run 0 | Step 4818 | Epoch 00000 | Loss 0.1590
# Run 0 | Step 4824 | Epoch 00000 | Loss 0.1447
# Run 0 | Step 4830 | Epoch 00000 | Loss 0.2442
# Run 0 | Step 4836 | Epoch 00000 | Loss 0.1615
# Run 0 | Step 4842 | Epoch 00000 | Loss 0.1768
# Run 0 | Step 4848 | Epoch 00000 | Loss 0.2099
# Run 0 | Step 4854 | Epoch 00000 | Loss 0.1385
# Run 0 | Step 4860 | Epoch 00000 | Loss 0.1529
# Run 0 | Step 4866 | Epoch 00000 | Loss 0.1689
# Run 0 | Step 4872 | Epoch 00000 | Loss 0.1436
# Run 0 | Step 4878 | Epoch 00000 | Loss 0.1639
# Run 0 | Step 4884 | Epoch 00000 | Loss 0.1840
# Run 0 | Step 4890 | Epoch 00000 | Loss 0.1799
# Run 0 | Step 4896 | Epoch 00000 | Loss 0.1430
# Run 0 | Step 4902 | Epoch 00000 | Loss 0.2042
# Run 0 | Step 4908 | Epoch 00000 | Loss 0.1479
# Run 0 | Step 4914 | Epoch 00000 | Loss 0.1491
# Run 0 | Step 4920 | Epoch 00000 | Loss 0.1883
# Run 0 | Step 4926 | Epoch 00000 | Loss 0.1831
# Run 0 | Step 4932 | Epoch 00000 | Loss 0.1739
# Run 0 | Step 4938 | Epoch 00000 | Loss 0.1987
# Run 0 | Step 4944 | Epoch 00000 | Loss 0.1164
# Run 0 | Step 4950 | Epoch 00000 | Loss 0.1876
# Run 0 | Step 4956 | Epoch 00000 | Loss 0.1829
# Run 0 | Step 4962 | Epoch 00000 | Loss 0.2435
# Run 0 | Step 4968 | Epoch 00000 | Loss 0.1976
# Run 0 | Step 4974 | Epoch 00000 | Loss 0.1769
# Run 0 | Step 4980 | Epoch 00000 | Loss 0.2420
# Run 0 | Step 4986 | Epoch 00000 | Loss 0.2178
# Run 0 | Step 4992 | Epoch 00000 | Loss 0.2402
# Run 0 | Step 4998 | Epoch 00000 | Loss 0.1777
# Run 0 | Step 5004 | Epoch 00000 | Loss 0.2239
# Run 0 | Step 5010 | Epoch 00000 | Loss 0.2309
# Run 0 | Step 5016 | Epoch 00000 | Loss 0.2536
# Run 0 | Step 5022 | Epoch 00000 | Loss 0.1751
# Run 0 | Step 5028 | Epoch 00000 | Loss 0.3176
# Run 0 | Step 5034 | Epoch 00000 | Loss 0.2534
# Run 0 | Step 5040 | Epoch 00000 | Loss 0.1777
# Run 0 | Step 5046 | Epoch 00000 | Loss 0.2132
# Run 0 | Step 5052 | Epoch 00000 | Loss 0.1797
# Run 0 | Step 5058 | Epoch 00000 | Loss 0.1917
# Run 0 | Step 5064 | Epoch 00000 | Loss 0.1634
# Run 0 | Step 5070 | Epoch 00000 | Loss 0.2686
# Run 0 | Step 5076 | Epoch 00000 | Loss 0.1631
# Run 0 | Step 5082 | Epoch 00000 | Loss 0.1703
# Run 0 | Step 5088 | Epoch 00000 | Loss 0.1397
# Run 0 | Step 5094 | Epoch 00000 | Loss 0.2001
# Run 0 | Step 5100 | Epoch 00000 | Loss 0.3012
# Run 0 | Step 5106 | Epoch 00000 | Loss 0.3012
# Run 0 | Step 5112 | Epoch 00000 | Loss 0.1953
# Run 0 | Step 5118 | Epoch 00000 | Loss 0.1966
# Run 0 | Step 5124 | Epoch 00000 | Loss 0.3074
# Run 0 | Step 5130 | Epoch 00000 | Loss 0.2295
# Run 0 | Step 5136 | Epoch 00000 | Loss 0.2603
# Run 0 | Step 5142 | Epoch 00000 | Loss 0.2431
# Run 0 | Step 5148 | Epoch 00000 | Loss 0.2429
# Run 0 | Step 5154 | Epoch 00000 | Loss 0.2026
# Run 0 | Step 5160 | Epoch 00000 | Loss 0.2680
# Run 0 | Step 5166 | Epoch 00000 | Loss 0.2770
# Run 0 | Step 5172 | Epoch 00000 | Loss 0.2023
# Run 0 | Step 5178 | Epoch 00000 | Loss 0.2181
# Run 0 | Step 5184 | Epoch 00000 | Loss 0.3024
# Run 0 | Step 5190 | Epoch 00000 | Loss 0.2766
# Run 0 | Step 5196 | Epoch 00000 | Loss 0.2804
# Run 0 | Step 5202 | Epoch 00000 | Loss 0.2110
# Run 0 | Step 5208 | Epoch 00000 | Loss 0.1978
# Run 0 | Step 5214 | Epoch 00000 | Loss 0.1942
# Run 0 | Step 5220 | Epoch 00000 | Loss 0.1682
# Run 0 | Step 5226 | Epoch 00000 | Loss 0.2057
# Run 0 | Step 5232 | Epoch 00000 | Loss 0.2537
# Run 0 | Step 5238 | Epoch 00000 | Loss 0.2172
# Run 0 | Step 5244 | Epoch 00000 | Loss 0.2253
# Run 0 | Step 5250 | Epoch 00000 | Loss 0.1573
# Run 0 | Step 5256 | Epoch 00000 | Loss 0.2038
# Run 0 | Step 5262 | Epoch 00000 | Loss 0.1481
# Run 0 | Step 5268 | Epoch 00000 | Loss 0.2342
# Run 0 | Step 5274 | Epoch 00000 | Loss 0.1933
# Run 0 | Step 5280 | Epoch 00000 | Loss 0.2041
# Run 0 | Step 5286 | Epoch 00000 | Loss 0.2013
# Run 0 | Step 5292 | Epoch 00000 | Loss 0.2367
# Run 0 | Step 5298 | Epoch 00000 | Loss 0.2169
# Run 0 | Step 5304 | Epoch 00000 | Loss 0.2021
# Run 0 | Step 5310 | Epoch 00000 | Loss 0.2987
# Run 0 | Step 5316 | Epoch 00000 | Loss 0.2000
# Run 0 | Step 5322 | Epoch 00000 | Loss 0.1929
# Run 0 | Step 5328 | Epoch 00000 | Loss 0.2387
# Run 0 | Step 5334 | Epoch 00000 | Loss 0.2022
# Run 0 | Step 5340 | Epoch 00000 | Loss 0.2354
# Run 0 | Step 5346 | Epoch 00000 | Loss 0.2269
# Run 0 | Step 5352 | Epoch 00000 | Loss 0.1475
# Run 0 | Step 5358 | Epoch 00000 | Loss 0.2073
# Run 0 | Step 5364 | Epoch 00000 | Loss 0.2599
# Run 0 | Step 5370 | Epoch 00000 | Loss 0.2470
# Run 0 | Step 5376 | Epoch 00000 | Loss 0.2880
# Run 0 | Step 5382 | Epoch 00000 | Loss 0.2715
# Run 0 | Step 5388 | Epoch 00000 | Loss 0.1944
# Run 0 | Step 5394 | Epoch 00000 | Loss 0.1943
# Run 0 | Step 5400 | Epoch 00000 | Loss 0.2055
# Run 0 | Step 5406 | Epoch 00000 | Loss 0.1857
# Run 0 | Step 5412 | Epoch 00000 | Loss 0.1793
# Run 0 | Step 5418 | Epoch 00000 | Loss 0.1486
# Run 0 | Step 5424 | Epoch 00000 | Loss 0.1650
# Run 0 | Step 5430 | Epoch 00000 | Loss 0.1674
# Run 0 | Step 5436 | Epoch 00000 | Loss 0.1840
# Run 0 | Step 5442 | Epoch 00000 | Loss 0.2110
# Run 0 | Step 5448 | Epoch 00000 | Loss 0.2095
# Run 0 | Step 5454 | Epoch 00000 | Loss 0.2152
# Run 0 | Step 5460 | Epoch 00000 | Loss 0.1862
# Run 0 | Step 5466 | Epoch 00000 | Loss 0.1993
# Run 0 | Step 5472 | Epoch 00000 | Loss 0.2918
# Run 0 | Step 5478 | Epoch 00000 | Loss 0.2010
# Run 0 | Step 5484 | Epoch 00000 | Loss 0.2679
# Run 0 | Step 5490 | Epoch 00000 | Loss 0.2871
# Run 0 | Step 5496 | Epoch 00000 | Loss 0.2372
# Run 0 | Step 5502 | Epoch 00000 | Loss 0.2567
# Run 0 | Step 5508 | Epoch 00000 | Loss 0.2489
# Run 0 | Step 5514 | Epoch 00000 | Loss 0.3187
# Run 0 | Step 5520 | Epoch 00000 | Loss 0.2637
# Run 0 | Step 5526 | Epoch 00000 | Loss 0.3718
# Run 0 | Step 5532 | Epoch 00000 | Loss 0.2548
# Run 0 | Step 5538 | Epoch 00000 | Loss 0.2060
# Run 0 | Step 5544 | Epoch 00000 | Loss 0.2667
# Run 0 | Step 5550 | Epoch 00000 | Loss 0.2277
# Run 0 | Step 5556 | Epoch 00000 | Loss 0.2074
# Run 0 | Step 5562 | Epoch 00000 | Loss 0.2786
# Run 0 | Step 5568 | Epoch 00000 | Loss 0.1945
# Run 0 | Step 5574 | Epoch 00000 | Loss 0.2467
# Run 0 | Step 5580 | Epoch 00000 | Loss 0.3107
# Run 0 | Step 5586 | Epoch 00000 | Loss 0.2265
# Run 0 | Step 5592 | Epoch 00000 | Loss 0.1988
# Run 0 | Step 5598 | Epoch 00000 | Loss 0.1796
# Run 0 | Step 5604 | Epoch 00000 | Loss 0.2928
# Run 0 | Step 5610 | Epoch 00000 | Loss 0.2262
# Run 0 | Step 5616 | Epoch 00000 | Loss 0.2668
# Run 0 | Step 5622 | Epoch 00000 | Loss 0.1577
# Run 0 | Step 5628 | Epoch 00000 | Loss 0.2364
# Run 0 | Step 5634 | Epoch 00000 | Loss 0.2145
# Run 0 | Step 5640 | Epoch 00000 | Loss 0.1712
# Run 0 | Step 5646 | Epoch 00000 | Loss 0.1880
# Run 0 | Step 5652 | Epoch 00000 | Loss 0.2060
# Run 0 | Step 5658 | Epoch 00000 | Loss 0.1730
# Run 0 | Step 5664 | Epoch 00000 | Loss 0.2428
# Run 0 | Step 5670 | Epoch 00000 | Loss 0.1917
# Run 0 | Step 5676 | Epoch 00000 | Loss 0.1925
# Run 0 | Step 5682 | Epoch 00000 | Loss 0.1690
# Run 0 | Step 5688 | Epoch 00000 | Loss 0.2070
# Run 0 | Step 5694 | Epoch 00000 | Loss 0.2337
# Run 0 | Step 5700 | Epoch 00000 | Loss 0.2050
# Run 0 | Step 5706 | Epoch 00000 | Loss 0.1619
# Run 0 | Step 5712 | Epoch 00000 | Loss 0.2427
# Run 0 | Step 5718 | Epoch 00000 | Loss 0.1953
# Run 0 | Step 5724 | Epoch 00000 | Loss 0.2925
# Run 0 | Step 5730 | Epoch 00000 | Loss 0.2666
# Run 0 | Step 5736 | Epoch 00000 | Loss 0.2511
# Run 0 | Step 5742 | Epoch 00000 | Loss 0.2348
# Run 0 | Step 5748 | Epoch 00000 | Loss 0.1475
# Run 0 | Step 5754 | Epoch 00000 | Loss 0.1540
# Run 0 | Step 5760 | Epoch 00000 | Loss 0.1215
# Run 0 | Step 5766 | Epoch 00000 | Loss 0.1417
# Run 0 | Step 5772 | Epoch 00000 | Loss 0.1670
# Run 0 | Step 5778 | Epoch 00000 | Loss 0.1869
# Run 0 | Step 5784 | Epoch 00000 | Loss 0.1927
# Run 0 | Step 5790 | Epoch 00000 | Loss 0.1489
# Run 0 | Step 5796 | Epoch 00000 | Loss 0.1872
# Run 0 | Step 5802 | Epoch 00000 | Loss 0.1463
# Run 0 | Step 5808 | Epoch 00000 | Loss 0.1780
# Run 0 | Step 5814 | Epoch 00000 | Loss 0.1407
# Run 0 | Step 5820 | Epoch 00000 | Loss 0.2021
# Run 0 | Step 5826 | Epoch 00000 | Loss 0.1342
# Run 0 | Step 5832 | Epoch 00000 | Loss 0.1141
# Run 0 | Step 5838 | Epoch 00000 | Loss 0.1554
# Run 0 | Step 5844 | Epoch 00000 | Loss 0.1941
# Run 0 | Step 5850 | Epoch 00000 | Loss 0.1992
# Run 0 | Step 5856 | Epoch 00000 | Loss 0.1994
# Run 0 | Step 5862 | Epoch 00000 | Loss 0.2085
# Run 0 | Step 5868 | Epoch 00000 | Loss 0.2612
# Run 0 | Step 5874 | Epoch 00000 | Loss 0.3180
# Run 0 | Step 5880 | Epoch 00000 | Loss 0.1699
# Run 0 | Step 5886 | Epoch 00000 | Loss 0.1691
# Run 0 | Step 5892 | Epoch 00000 | Loss 0.2445
# Run 0 | Step 5898 | Epoch 00000 | Loss 0.2260
# Run 0 | Step 5904 | Epoch 00000 | Loss 0.2164
# Run 0 | Step 5910 | Epoch 00000 | Loss 0.1971
# Run 0 | Step 5916 | Epoch 00000 | Loss 0.2184
# Run 0 | Step 5922 | Epoch 00000 | Loss 0.2072
# Run 0 | Step 5928 | Epoch 00000 | Loss 0.2254
# Run 0 | Step 5934 | Epoch 00000 | Loss 0.2396
# Run 0 | Step 5940 | Epoch 00000 | Loss 0.2023
# Run 0 | Step 5946 | Epoch 00000 | Loss 0.1830
# Run 0 | Step 5952 | Epoch 00000 | Loss 0.1522
# Run 0 | Step 5958 | Epoch 00000 | Loss 0.1848
# Run 0 | Step 5964 | Epoch 00000 | Loss 0.2073
# Run 0 | Step 5970 | Epoch 00000 | Loss 0.2054
# Run 0 | Step 5976 | Epoch 00000 | Loss 0.3495
# Run 0 | Step 5982 | Epoch 00000 | Loss 0.1877
# Run 0 | Step 5988 | Epoch 00000 | Loss 0.2008
# Run 0 | Step 5994 | Epoch 00000 | Loss 0.1834
# Run 0 | Step 6000 | Epoch 00000 | Loss 0.1525
# Run 0 | Step 6006 | Epoch 00000 | Loss 0.1570
# Run 0 | Step 6012 | Epoch 00000 | Loss 0.2086
# Run 0 | Step 6018 | Epoch 00000 | Loss 0.1961
# Run 0 | Step 6024 | Epoch 00000 | Loss 0.1514
# Run 0 | Step 6030 | Epoch 00000 | Loss 0.1966
# Run 0 | Step 6036 | Epoch 00000 | Loss 0.2449
# Run 0 | Step 6042 | Epoch 00000 | Loss 0.2318
# Run 0 | Step 6048 | Epoch 00000 | Loss 0.2740
# Run 0 | Step 6054 | Epoch 00000 | Loss 0.2411
# Run 0 | Step 6060 | Epoch 00000 | Loss 0.2644
# Run 0 | Step 6066 | Epoch 00000 | Loss 0.1842
# Run 0 | Step 6072 | Epoch 00000 | Loss 0.1854
# Run 0 | Step 6078 | Epoch 00000 | Loss 0.2688
# Run 0 | Step 6084 | Epoch 00000 | Loss 0.2067
# Run 0 | Step 6090 | Epoch 00000 | Loss 0.2251
# Run 0 | Step 6096 | Epoch 00000 | Loss 0.2400
# Run 0 | Step 6102 | Epoch 00000 | Loss 0.1869
# Run 0 | Step 6108 | Epoch 00000 | Loss 0.1835
# Run 0 | Step 6114 | Epoch 00000 | Loss 0.1942
# Run 0 | Step 6120 | Epoch 00000 | Loss 0.1463
# Run 0 | Step 6126 | Epoch 00000 | Loss 0.1548
# Run 0 | Step 6132 | Epoch 00000 | Loss 0.1410
# Run 0 | Step 6138 | Epoch 00000 | Loss 0.1897
# Run 0 | Step 6144 | Epoch 00000 | Loss 0.1833
# Run 0 | Step 6150 | Epoch 00000 | Loss 0.2250
# Run 0 | Step 6156 | Epoch 00000 | Loss 0.2177
# Run 0 | Step 6162 | Epoch 00000 | Loss 0.2517
# Run 0 | Step 6168 | Epoch 00000 | Loss 0.2484
# Run 0 | Step 6174 | Epoch 00000 | Loss 0.2404
# Run 0 | Step 6180 | Epoch 00000 | Loss 0.2640
# Run 0 | Step 6186 | Epoch 00000 | Loss 0.2348
# Run 0 | Step 6192 | Epoch 00000 | Loss 0.1987
# Run 0 | Step 6198 | Epoch 00000 | Loss 0.2577
# ...
# Run 0 | Step 7440 | Epoch 00000 | Loss 0.2170
# Run 0 | Step 7446 | Epoch 00000 | Loss 0.2250
# Run 0 | Step 7452 | Epoch 00000 | Loss 0.1918
# Run 0 | Step 7458 | Epoch 00000 | Loss 0.1957
# Run 0 | Step 7464 | Epoch 00000 | Loss 0.1765
# Run 0 | Step 7470 | Epoch 00000 | Loss 0.1495
# Run 0 | Step 7476 | Epoch 00000 | Loss 0.1976
# Run 0 | Step 7482 | Epoch 00000 | Loss 0.2231
# Run 0 | Step 7488 | Epoch 00000 | Loss 0.1868
# Run 0 | Step 7494 | Epoch 00000 | Loss 0.1883
# Run 0 | Step 7500 | Epoch 00000 | Loss 0.1958
# Run 0 | Step 7506 | Epoch 00000 | Loss 0.1766
# Run 0 | Step 7512 | Epoch 00000 | Loss 0.2157
# Run 0 | Step 7518 | Epoch 00000 | Loss 0.1956
# Run 0 | Step 7524 | Epoch 00000 | Loss 0.2461
# Run 0 | Step 7530 | Epoch 00000 | Loss 0.2053
# Run 0 | Step 7536 | Epoch 00000 | Loss 0.1433
# Run 0 | Step 7542 | Epoch 00000 | Loss 0.1285
# Run 0 | Step 7548 | Epoch 00000 | Loss 0.1406
# Run 0 | Step 7554 | Epoch 00000 | Loss 0.1527
# Run 0 | Step 7560 | Epoch 00000 | Loss 0.1147
# Run 0 | Step 7566 | Epoch 00000 | Loss 0.1310
# Run 0 | Step 7572 | Epoch 00000 | Loss 0.2005
# Run 0 | Step 7578 | Epoch 00000 | Loss 0.2188
# Run 0 | Step 7584 | Epoch 00000 | Loss 0.2039
# Run 0 | Step 7590 | Epoch 00000 | Loss 0.2010
# Run 0 | Step 7596 | Epoch 00000 | Loss 0.1667
# Run 0 | Step 7602 | Epoch 00000 | Loss 0.2227
# Run 0 | Step 7608 | Epoch 00000 | Loss 0.1770
# Run 0 | Step 7614 | Epoch 00000 | Loss 0.2421
# Run 0 | Step 7620 | Epoch 00000 | Loss 0.2244
# Run 0 | Step 7626 | Epoch 00000 | Loss 0.1995
# Run 0 | Step 7632 | Epoch 00000 | Loss 0.2079
# Run 0 | Step 7638 | Epoch 00000 | Loss 0.2457
# Run 0 | Step 7644 | Epoch 00000 | Loss 0.2187
# Run 0 | Step 7650 | Epoch 00000 | Loss 0.1995
# Run 0 | Step 7656 | Epoch 00000 | Loss 0.2214
# Run 0 | Step 7662 | Epoch 00000 | Loss 0.1448
# Run 0 | Step 7668 | Epoch 00000 | Loss 0.1780
# Run 0 | Step 7674 | Epoch 00000 | Loss 0.1478
# Run 0 | Step 7680 | Epoch 00000 | Loss 0.1249
# Run 0 | Step 7686 | Epoch 00000 | Loss 0.1416
# Run 0 | Step 7692 | Epoch 00000 | Loss 0.1233
# Run 0 | Step 7698 | Epoch 00000 | Loss 0.1516
# Run 0 | Step 7704 | Epoch 00000 | Loss 0.1160
# Run 0 | Step 7710 | Epoch 00000 | Loss 0.1190
# Run 0 | Step 7716 | Epoch 00000 | Loss 0.1169
# Run 0 | Step 7722 | Epoch 00000 | Loss 0.1021
# Run 0 | Step 7728 | Epoch 00000 | Loss 0.1692
# Run 0 | Step 7734 | Epoch 00000 | Loss 0.2223
# Run 0 | Step 7740 | Epoch 00000 | Loss 0.1289
# Run 0 | Step 7746 | Epoch 00000 | Loss 0.1645
# Run 0 | Step 7752 | Epoch 00000 | Loss 0.1585
# Run 0 | Step 7758 | Epoch 00000 | Loss 0.1478
# Run 0 | Step 7764 | Epoch 00000 | Loss 0.1531
# Run 0 | Step 7770 | Epoch 00000 | Loss 0.1157
# Run 0 | Step 7776 | Epoch 00000 | Loss 0.1300
# Run 0 | Step 7782 | Epoch 00000 | Loss 0.1654
# Run 0 | Step 7788 | Epoch 00000 | Loss 0.1319
# Run 0 | Step 7794 | Epoch 00000 | Loss 0.1513
# Run 0 | Step 7800 | Epoch 00000 | Loss 0.1454
# Run 0 | Step 7806 | Epoch 00000 | Loss 0.1525
# Run 0 | Step 7812 | Epoch 00000 | Loss 0.1383
# Run 0 | Step 7818 | Epoch 00000 | Loss 0.1358
# Run 0 | Step 7824 | Epoch 00000 | Loss 0.1402
# Run 0 | Step 7830 | Epoch 00000 | Loss 0.1595
# Run 0 | Step 7836 | Epoch 00000 | Loss 0.1759
# Run 0 | Step 7842 | Epoch 00000 | Loss 0.1754
# Run 0 | Step 7848 | Epoch 00000 | Loss 0.1265
# Run 0 | Step 7854 | Epoch 00000 | Loss 0.1330
# Run 0 | Step 7860 | Epoch 00000 | Loss 0.1686
# Run 0 | Step 7866 | Epoch 00000 | Loss 0.2015
# Run 0 | Step 7872 | Epoch 00000 | Loss 0.1750
# Run 0 | Step 7878 | Epoch 00000 | Loss 0.1497
# Run 0 | Step 7884 | Epoch 00000 | Loss 0.1278
# Run 0 | Step 7890 | Epoch 00000 | Loss 0.1336
# Run 0 | Step 7896 | Epoch 00000 | Loss 0.1381
# Run 0 | Step 7902 | Epoch 00000 | Loss 0.1838
# Run 0 | Step 7908 | Epoch 00000 | Loss 0.1294
# Run 0 | Step 7914 | Epoch 00000 | Loss 0.1750
# Run 0 | Step 7920 | Epoch 00000 | Loss 0.1033
# Run 0 | Step 7926 | Epoch 00000 | Loss 0.1172
# Run 0 | Step 7932 | Epoch 00000 | Loss 0.1118
# Run 0 | Step 7938 | Epoch 00000 | Loss 0.1903
# Run 0 | Step 7944 | Epoch 00000 | Loss 0.1444
# Run 0 | Step 7950 | Epoch 00000 | Loss 0.1598
# Run 0 | Step 7956 | Epoch 00000 | Loss 0.1696
# Run 0 | Step 7962 | Epoch 00000 | Loss 0.1387
# Run 0 | Step 7968 | Epoch 00000 | Loss 0.1768
# Run 0 | Step 7974 | Epoch 00000 | Loss 0.2842
# Run 0 | Step 7980 | Epoch 00000 | Loss 0.1812
# Run 0 | Step 7986 | Epoch 00000 | Loss 0.2385
# Run 0 | Step 7992 | Epoch 00000 | Loss 0.2345
# Run 0 | Step 7998 | Epoch 00000 | Loss 0.2373
# Run 0 | Step 8004 | Epoch 00000 | Loss 0.2505
# Run 0 | Step 8010 | Epoch 00000 | Loss 0.2282
# Run 0 | Step 8016 | Epoch 00000 | Loss 0.2217
# Run 0 | Step 8022 | Epoch 00000 | Loss 0.1757
# Run 0 | Step 8028 | Epoch 00000 | Loss 0.2060
# Run 0 | Step 8034 | Epoch 00000 | Loss 0.1410
# Run 0 | Step 8040 | Epoch 00000 | Loss 0.1870
# Run 0 | Step 8046 | Epoch 00000 | Loss 0.1681
# Run 0 | Step 8052 | Epoch 00000 | Loss 0.1660
# Run 0 | Step 8058 | Epoch 00000 | Loss 0.1599
# Run 0 | Step 8064 | Epoch 00000 | Loss 0.1720
# Run 0 | Step 8070 | Epoch 00000 | Loss 0.2420
# Run 0 | Step 8076 | Epoch 00000 | Loss 0.1578
# Run 0 | Step 8082 | Epoch 00000 | Loss 0.1346
# Run 0 | Step 8088 | Epoch 00000 | Loss 0.1327
# Run 0 | Step 8094 | Epoch 00000 | Loss 0.1600
# Run 0 | Step 8100 | Epoch 00000 | Loss 0.1530
# Run 0 | Step 8106 | Epoch 00000 | Loss 0.1523
# Run 0 | Step 8112 | Epoch 00000 | Loss 0.1393
# Run 0 | Step 8118 | Epoch 00000 | Loss 0.1434
# Run 0 | Step 8124 | Epoch 00000 | Loss 0.1245
# Run 0 | Step 8130 | Epoch 00000 | Loss 0.1052
# Run 0 | Step 8136 | Epoch 00000 | Loss 0.1805
# Run 0 | Step 8142 | Epoch 00000 | Loss 0.1243
# Run 0 | Step 8148 | Epoch 00000 | Loss 0.1244
# Run 0 | Step 8154 | Epoch 00000 | Loss 0.0951
# Run 0 | Step 8160 | Epoch 00000 | Loss 0.1554
# Run 0 | Step 8166 | Epoch 00000 | Loss 0.1449
# Run 0 | Step 8172 | Epoch 00000 | Loss 0.1026
# Run 0 | Step 8178 | Epoch 00000 | Loss 0.1497
# Run 0 | Step 8184 | Epoch 00000 | Loss 0.1455
# Run 0 | Step 8190 | Epoch 00000 | Loss 0.1700
# Run 0 | Step 8196 | Epoch 00000 | Loss 0.1287
# Run 0 | Step 8202 | Epoch 00000 | Loss 0.1404
# Run 0 | Step 8208 | Epoch 00000 | Loss 0.1249
# Run 0 | Step 8214 | Epoch 00000 | Loss 0.1034
# Run 0 | Step 8220 | Epoch 00000 | Loss 0.1222
# Run 0 | Step 8226 | Epoch 00000 | Loss 0.1618
# Run 0 | Step 8232 | Epoch 00000 | Loss 0.1353
# Run 0 | Step 8238 | Epoch 00000 | Loss 0.1784
# Run 0 | Step 8244 | Epoch 00000 | Loss 0.2088
# Run 0 | Step 8250 | Epoch 00000 | Loss 0.1396
# Run 0 | Step 8256 | Epoch 00000 | Loss 0.1368
# Run 0 | Step 8262 | Epoch 00000 | Loss 0.1373
# Run 0 | Step 8268 | Epoch 00000 | Loss 0.1406
# Run 0 | Step 8274 | Epoch 00000 | Loss 0.1638
# Run 0 | Step 8280 | Epoch 00000 | Loss 0.2062
# Run 0 | Step 8286 | Epoch 00000 | Loss 0.1288
# Run 0 | Step 8292 | Epoch 00000 | Loss 0.0975
# Run 0 | Step 8298 | Epoch 00000 | Loss 0.1771
# Run 0 | Step 8304 | Epoch 00000 | Loss 0.1139
# Run 0 | Step 8310 | Epoch 00000 | Loss 0.1196
# Run 0 | Step 8316 | Epoch 00000 | Loss 0.1163
# Run 0 | Step 8322 | Epoch 00000 | Loss 0.0470
# Run 0 | Step 8328 | Epoch 00000 | Loss 0.0835
# Run 0 | Step 8334 | Epoch 00000 | Loss 0.0923
# Run 0 | Step 8340 | Epoch 00000 | Loss 0.1077
# Run 0 | Step 8346 | Epoch 00000 | Loss 0.1135
# Run 0 | Step 8352 | Epoch 00000 | Loss 0.1366
# Run 0 | Step 8358 | Epoch 00000 | Loss 0.0882
# Run 0 | Step 8364 | Epoch 00000 | Loss 0.1796
# Run 0 | Step 8370 | Epoch 00000 | Loss 0.1648
# Run 0 | Step 8376 | Epoch 00000 | Loss 0.1232
# Run 0 | Step 8382 | Epoch 00000 | Loss 0.1321
# Run 0 | Step 8388 | Epoch 00000 | Loss 0.0889
# Run 0 | Step 8394 | Epoch 00000 | Loss 0.0577
# Run 0 | Step 8400 | Epoch 00000 | Loss 0.1278
# Run 0 | Step 8406 | Epoch 00000 | Loss 0.0931
# Run 0 | Step 8412 | Epoch 00000 | Loss 0.0942
# Run 0 | Step 8418 | Epoch 00000 | Loss 0.0776
# Run 0 | Step 8424 | Epoch 00000 | Loss 0.0898
# Run 0 | Step 8430 | Epoch 00000 | Loss 0.1225
# Run 0 | Step 8436 | Epoch 00000 | Loss 0.0922
# Run 0 | Step 8442 | Epoch 00000 | Loss 0.1212
# Run 0 | Step 8448 | Epoch 00000 | Loss 0.1256
# Run 0 | Step 8454 | Epoch 00000 | Loss 0.1091
# Run 0 | Step 8460 | Epoch 00000 | Loss 0.1603
# Run 0 | Step 8466 | Epoch 00000 | Loss 0.1430
# Run 0 | Step 8472 | Epoch 00000 | Loss 0.0919
# Run 0 | Step 8478 | Epoch 00000 | Loss 0.0874
# Run 0 | Step 8484 | Epoch 00000 | Loss 0.1430
# Run 0 | Step 8490 | Epoch 00000 | Loss 0.0910
# Run 0 | Step 8496 | Epoch 00000 | Loss 0.1202
# Run 0 | Step 8502 | Epoch 00000 | Loss 0.1248
# Run 0 | Step 8508 | Epoch 00000 | Loss 0.1096
# Run 0 | Step 8514 | Epoch 00000 | Loss 0.0925
# Run 0 | Step 8520 | Epoch 00000 | Loss 0.0933
# Run 0 | Step 8526 | Epoch 00000 | Loss 0.1007
# Run 0 | Step 8532 | Epoch 00000 | Loss 0.0966
# Run 0 | Step 8538 | Epoch 00000 | Loss 0.0902
# Run 0 | Step 8544 | Epoch 00000 | Loss 0.1262
# Run 0 | Step 8550 | Epoch 00000 | Loss 0.1193
# Run 0 | Step 8556 | Epoch 00000 | Loss 0.0966
# Run 0 | Step 8562 | Epoch 00000 | Loss 0.1420
# Run 0 | Step 8568 | Epoch 00000 | Loss 0.1842
# Run 0 | Step 8574 | Epoch 00000 | Loss 0.1576
# Run 0 | Step 8580 | Epoch 00000 | Loss 0.1326
# Run 0 | Step 8586 | Epoch 00000 | Loss 0.1470
# Run 0 | Step 8592 | Epoch 00000 | Loss 0.1130
# Run 0 | Step 8598 | Epoch 00000 | Loss 0.1361
# Run 0 | Step 8604 | Epoch 00000 | Loss 0.1547
# Run 0 | Step 8610 | Epoch 00000 | Loss 0.0981
# Run 0 | Step 8616 | Epoch 00000 | Loss 0.0944
# Run 0 | Step 8622 | Epoch 00000 | Loss 0.1275
# Run 0 | Step 8628 | Epoch 00000 | Loss 0.1388
# Run 0 | Step 8634 | Epoch 00000 | Loss 0.1457
# Run 1 | Step 0 | Epoch 00000 | Loss 0.0114
# Run 1 | Step 6 | Epoch 00000 | Loss 0.0139
# Run 1 | Step 12 | Epoch 00000 | Loss 0.0401
# Run 1 | Step 18 | Epoch 00000 | Loss 0.0350
# Run 1 | Step 24 | Epoch 00000 | Loss 0.0552
# Run 1 | Step 30 | Epoch 00000 | Loss 0.0935
# Run 1 | Step 36 | Epoch 00000 | Loss 0.0836
# Run 1 | Step 42 | Epoch 00000 | Loss 0.1003
# Run 1 | Step 48 | Epoch 00000 | Loss 0.1599
# Run 1 | Step 54 | Epoch 00000 | Loss 0.1610
# Run 1 | Step 60 | Epoch 00000 | Loss 0.1461
# Run 1 | Step 66 | Epoch 00000 | Loss 0.1437
# Run 1 | Step 72 | Epoch 00000 | Loss 0.1490
# Run 1 | Step 78 | Epoch 00000 | Loss 0.1719
# Run 1 | Step 84 | Epoch 00000 | Loss 0.2339
# Run 1 | Step 90 | Epoch 00000 | Loss 0.2066
# Run 1 | Step 96 | Epoch 00000 | Loss 0.2134
# Run 1 | Step 102 | Epoch 00000 | Loss 0.2197
# Run 1 | Step 108 | Epoch 00000 | Loss 0.2045
# Run 1 | Step 114 | Epoch 00000 | Loss 0.2466
# Run 1 | Step 120 | Epoch 00000 | Loss 0.2269
# Run 1 | Step 126 | Epoch 00000 | Loss 0.2047
# Run 1 | Step 132 | Epoch 00000 | Loss 0.2589
# Run 1 | Step 138 | Epoch 00000 | Loss 0.2881
# Run 1 | Step 144 | Epoch 00000 | Loss 0.2744
# Run 1 | Step 150 | Epoch 00000 | Loss 0.2155
# Run 1 | Step 156 | Epoch 00000 | Loss 0.3349
# Run 1 | Step 162 | Epoch 00000 | Loss 0.2688
# Run 1 | Step 168 | Epoch 00000 | Loss 0.2252
# Run 1 | Step 174 | Epoch 00000 | Loss 0.2301
# Run 1 | Step 180 | Epoch 00000 | Loss 0.2382
# Run 1 | Step 186 | Epoch 00000 | Loss 0.2455
# Run 1 | Step 192 | Epoch 00000 | Loss 0.2947
# Run 1 | Step 198 | Epoch 00000 | Loss 0.3270
# Run 1 | Step 204 | Epoch 00000 | Loss 0.2796
# Run 1 | Step 210 | Epoch 00000 | Loss 0.2452
# Run 1 | Step 216 | Epoch 00000 | Loss 0.2642
# Run 1 | Step 222 | Epoch 00000 | Loss 0.2492
# Run 1 | Step 228 | Epoch 00000 | Loss 0.2906
# Run 1 | Step 234 | Epoch 00000 | Loss 0.2311
# Run 1 | Step 240 | Epoch 00000 | Loss 0.2214
# Run 1 | Step 246 | Epoch 00000 | Loss 0.2474
# Run 1 | Step 252 | Epoch 00000 | Loss 0.2824
# Run 1 | Step 258 | Epoch 00000 | Loss 0.2341
# Run 1 | Step 264 | Epoch 00000 | Loss 0.2067
# Run 1 | Step 270 | Epoch 00000 | Loss 0.2260
# Run 1 | Step 276 | Epoch 00000 | Loss 0.2454
# Run 1 | Step 282 | Epoch 00000 | Loss 0.2238
# Run 1 | Step 288 | Epoch 00000 | Loss 0.2945
# Run 1 | Step 294 | Epoch 00000 | Loss 0.2875
# Run 1 | Step 300 | Epoch 00000 | Loss 0.2173
# Run 1 | Step 306 | Epoch 00000 | Loss 0.2706
# Run 1 | Step 312 | Epoch 00000 | Loss 0.3084
# Run 1 | Step 318 | Epoch 00000 | Loss 0.2379
# Run 1 | Step 324 | Epoch 00000 | Loss 0.3155
# Run 1 | Step 330 | Epoch 00000 | Loss 0.2772
# Run 1 | Step 336 | Epoch 00000 | Loss 0.2207
# Run 1 | Step 342 | Epoch 00000 | Loss 0.2326
# Run 1 | Step 348 | Epoch 00000 | Loss 0.3148
# Run 1 | Step 354 | Epoch 00000 | Loss 0.2581
# Run 1 | Step 360 | Epoch 00000 | Loss 0.1744
# Run 1 | Step 366 | Epoch 00000 | Loss 0.2547
# Run 1 | Step 372 | Epoch 00000 | Loss 0.2200
# Run 1 | Step 378 | Epoch 00000 | Loss 0.2931
# Run 1 | Step 384 | Epoch 00000 | Loss 0.3001
# Run 1 | Step 390 | Epoch 00000 | Loss 0.2811
# Run 1 | Step 396 | Epoch 00000 | Loss 0.2464
# Run 1 | Step 402 | Epoch 00000 | Loss 0.1913
# Run 1 | Step 408 | Epoch 00000 | Loss 0.2906
# Run 1 | Step 414 | Epoch 00000 | Loss 0.2747
# Run 1 | Step 420 | Epoch 00000 | Loss 0.2736
# Run 1 | Step 426 | Epoch 00000 | Loss 0.2421
# Run 1 | Step 432 | Epoch 00000 | Loss 0.2559
# Run 1 | Step 438 | Epoch 00000 | Loss 0.2491
# Run 1 | Step 444 | Epoch 00000 | Loss 0.2174
# Run 1 | Step 450 | Epoch 00000 | Loss 0.2390
# Run 1 | Step 456 | Epoch 00000 | Loss 0.2162
# Run 1 | Step 462 | Epoch 00000 | Loss 0.2642
# Run 1 | Step 468 | Epoch 00000 | Loss 0.2406
# Run 1 | Step 474 | Epoch 00000 | Loss 0.2197
# Run 1 | Step 480 | Epoch 00000 | Loss 0.2671
# Run 1 | Step 486 | Epoch 00000 | Loss 0.2843
# Run 1 | Step 492 | Epoch 00000 | Loss 0.2604
# Run 1 | Step 498 | Epoch 00000 | Loss 0.2706
# Run 1 | Step 504 | Epoch 00000 | Loss 0.2573
# Run 1 | Step 510 | Epoch 00000 | Loss 0.2132
# Run 1 | Step 516 | Epoch 00000 | Loss 0.2519
# Run 1 | Step 522 | Epoch 00000 | Loss 0.2160
# Run 1 | Step 528 | Epoch 00000 | Loss 0.2070
# Run 1 | Step 534 | Epoch 00000 | Loss 0.2229
# Run 1 | Step 540 | Epoch 00000 | Loss 0.1789
# Run 1 | Step 546 | Epoch 00000 | Loss 0.2253
# Run 1 | Step 552 | Epoch 00000 | Loss 0.2564
# Run 1 | Step 558 | Epoch 00000 | Loss 0.2493
# Run 1 | Step 564 | Epoch 00000 | Loss 0.2078
# Run 1 | Step 570 | Epoch 00000 | Loss 0.2051
# Run 1 | Step 576 | Epoch 00000 | Loss 0.2948
# Run 1 | Step 582 | Epoch 00000 | Loss 0.2206
# Run 1 | Step 588 | Epoch 00000 | Loss 0.2064
# Run 1 | Step 594 | Epoch 00000 | Loss 0.2650
# Run 1 | Step 600 | Epoch 00000 | Loss 0.2445
# Run 1 | Step 606 | Epoch 00000 | Loss 0.4026
# Run 1 | Step 612 | Epoch 00000 | Loss 0.2657
# Run 1 | Step 618 | Epoch 00000 | Loss 0.3625
# Run 1 | Step 624 | Epoch 00000 | Loss 0.2374
# Run 1 | Step 630 | Epoch 00000 | Loss 0.4148
# Run 1 | Step 636 | Epoch 00000 | Loss 0.2546
# Run 1 | Step 642 | Epoch 00000 | Loss 0.2823
# Run 1 | Step 648 | Epoch 00000 | Loss 0.2260
# Run 1 | Step 654 | Epoch 00000 | Loss 0.1944
# Run 1 | Step 660 | Epoch 00000 | Loss 0.2437
# Run 1 | Step 666 | Epoch 00000 | Loss 0.2076
# Run 1 | Step 672 | Epoch 00000 | Loss 0.2623
# Run 1 | Step 678 | Epoch 00000 | Loss 0.3221
# Run 1 | Step 684 | Epoch 00000 | Loss 0.2776
# Run 1 | Step 690 | Epoch 00000 | Loss 0.2082
# Run 1 | Step 696 | Epoch 00000 | Loss 0.2827
# Run 1 | Step 702 | Epoch 00000 | Loss 0.1623
# Run 1 | Step 708 | Epoch 00000 | Loss 0.2083
# Run 1 | Step 714 | Epoch 00000 | Loss 0.2620
# Run 1 | Step 720 | Epoch 00000 | Loss 0.2838
# Run 1 | Step 726 | Epoch 00000 | Loss 0.2259
# Run 1 | Step 732 | Epoch 00000 | Loss 0.3271
# Run 1 | Step 738 | Epoch 00000 | Loss 0.3051
# Run 1 | Step 744 | Epoch 00000 | Loss 0.3784
# Run 1 | Step 750 | Epoch 00000 | Loss 0.2884
# Run 1 | Step 756 | Epoch 00000 | Loss 0.2486
# Run 1 | Step 762 | Epoch 00000 | Loss 0.2396
# Run 1 | Step 768 | Epoch 00000 | Loss 0.2679
# Run 1 | Step 774 | Epoch 00000 | Loss 0.2642
# Run 1 | Step 780 | Epoch 00000 | Loss 0.3603
# Run 1 | Step 786 | Epoch 00000 | Loss 0.3269
# Run 1 | Step 792 | Epoch 00000 | Loss 0.3539
# Run 1 | Step 798 | Epoch 00000 | Loss 0.3603
# Run 1 | Step 804 | Epoch 00000 | Loss 0.2487
# Run 1 | Step 810 | Epoch 00000 | Loss 0.2414
# Run 1 | Step 816 | Epoch 00000 | Loss 0.2731
# Run 1 | Step 822 | Epoch 00000 | Loss 0.3235
# Run 1 | Step 828 | Epoch 00000 | Loss 0.2524
# Run 1 | Step 834 | Epoch 00000 | Loss 0.2759
# Run 1 | Step 840 | Epoch 00000 | Loss 0.2051
# Run 1 | Step 846 | Epoch 00000 | Loss 0.1662
# Run 1 | Step 852 | Epoch 00000 | Loss 0.2503
# Run 1 | Step 858 | Epoch 00000 | Loss 0.2315
# Run 1 | Step 864 | Epoch 00000 | Loss 0.1824
# Run 1 | Step 870 | Epoch 00000 | Loss 0.1600
# Run 1 | Step 876 | Epoch 00000 | Loss 0.2280
# Run 1 | Step 882 | Epoch 00000 | Loss 0.2391
# Run 1 | Step 888 | Epoch 00000 | Loss 0.2093
# Run 1 | Step 894 | Epoch 00000 | Loss 0.2616
# Run 1 | Step 900 | Epoch 00000 | Loss 0.2321

# %%
for param in net.named_parameters():
    if param[0] == 'gcn.predict_leaving.embed.weight':
        break

# %%
E = param[1][:]

# %%
E[123]

# %%
with open('embeddings_GATFlow_4step_10s_mse_002.pkl','wb') as f:
    pickle.dump(E, f)
